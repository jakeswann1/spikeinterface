# %% [markdown]
# # SpikeInterface Processing Pipeline for Tetrodes & Neuronexus Probe
# ### Jake Swann

# %% [markdown]
# #### Run axona_spikeinterface script on all recordings marked on a spreadsheet
# - See single-recording script for more details

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) #gets rid of some annoying warnings
import pandas as pd
import numpy as np
import spikeinterface as si
import spikeinterface.extractors as se
from pathlib import Path
from utils import *
import os
import phy.apps.kwik

# %matplotlib widget

sheet = pd.read_excel('probe_data_IV.xlsx')
sheet_inc = sheet[sheet['include_spikeinterface'] == 'Y']

trial_list = sheet_inc['trial_name']. to_list()
session_list = np.unique([i[:6] for i in trial_list])    

# Collect into sessions and preprocess
recording_list = []
for i,session in enumerate(session_list):
    recording_list.append([])
    for j in trial_list:
        if session in j:
            base_folder = sheet_inc[sheet_inc['trial_name'] == j]['path'].tolist()[0]
            
            recording_list[i].append([preprocess(recording = se.read_axona(f"{base_folder}/{j}.set"),
                                     recording_name = j,
                                     base_folder = base_folder,
                                     electrode_type = sheet_inc[sheet_inc['trial_name'] == j]['probe_type'].tolist()[0]),
                                     j, base_folder])
                                     

# Concatenate over a single session and sort
recordings_concat = []
for i, recording in enumerate(recording_list):
    session = pd.DataFrame(recording_list[0])
    
    recordings_concat.append(si.concatenate_recordings(session.iloc[:,0]))
    for j, concat in enumerate(recordings_concat):
        print(f'Sorting {concat}')
        sort(recording = concat, 
             recording_name = session_list[j], 
             base_folder = session.iloc[0,2], 
             sorting_suffix = 'sorting_1.5_4')
print(session)
# Out:
# /home/isabella/Documents/isabella/klusta_testdata/220624a_famBox_preprocessed
# 32-channel 32 ch four shanks recording loaded from previous preprocessing
# BinaryFolderRecording: 32 channels - 1 segments - 48.0kHz - 900.062s
# /home/isabella/Documents/isabella/klusta_testdata/220624b_famBox_preprocessed
# 32-channel 32 ch four shanks recording loaded from previous preprocessing
# BinaryFolderRecording: 32 channels - 1 segments - 48.0kHz - 900.062s
# /home/isabella/Documents/isabella/klusta_testdata/220624c_diffBox_preprocessed
# 32-channel 32 ch four shanks recording loaded from previous preprocessing
# BinaryFolderRecording: 32 channels - 1 segments - 48.0kHz - 900.062s
# /home/isabella/Documents/isabella/klusta_testdata/220624d_CCE_preprocessed
# 32-channel 32 ch four shanks recording loaded from previous preprocessing
# BinaryFolderRecording: 32 channels - 1 segments - 48.0kHz - 900.062s
# /home/isabella/Documents/isabella/klusta_testdata/220624e_famBox_preprocessed
# 32-channel 32 ch four shanks recording loaded from previous preprocessing
# BinaryFolderRecording: 32 channels - 1 segments - 48.0kHz - 900.062s
# /home/isabella/Documents/isabella/klusta_testdata/220624g_sleepHP_preprocessed
# 32-channel 32 ch four shanks recording loaded from previous preprocessing
# BinaryFolderRecording: 32 channels - 1 segments - 48.0kHz - 1200.062s
# /home/isabella/Documents/isabella/klusta_testdata/220624h_sleepHP_preprocessed
# 32-channel 32 ch four shanks recording loaded from previous preprocessing
# BinaryFolderRecording: 32 channels - 1 segments - 48.0kHz - 1200.062s
# Sorting ConcatenateSegmentRecording: 32 channels - 1 segments - 48.0kHz - 6900.438s
# write_binary_recording:   0%|          | 0/6901 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/klusta_testdata/220624_sorting_1.5_4/run_klusta.sh
# 18:42:02 [I] creator:446          Using kwik file `/data/isabella/klusta_testdata/220624_sorting_1.5_4/recording.kwik`.
#
# 18:42:02 [I] launch:206           Starting spike detection.
#
# 18:42:02 [I] launch:53            SpikeDetekt parameters:
#
# 18:42:02 [I] launch:55            chunk_overlap_seconds = 0.015
#
# 18:42:02 [I] launch:55            chunk_size_seconds = 3
#
# 18:42:02 [I] launch:55            connected_component_join_size = 1
#
# 18:42:02 [I] launch:55            detect_spikes = negative
#
# 18:42:02 [I] launch:55            dtype = int16
#
# 18:42:02 [I] launch:55            excerpt_size_seconds = 1
#
# 18:42:02 [I] launch:55            experiment_name = recording.kwik
#
# 18:42:02 [I] launch:55            extract_s_after = 32
#
# 18:42:02 [I] launch:55            extract_s_before = 16
#
# 18:42:02 [I] launch:55            filter_butter_order = 3
#
# 18:42:02 [I] launch:55            filter_high_factor = 0.475
#
# 18:42:02 [I] launch:55            filter_low = 500.0
#
# 18:42:02 [I] launch:55            n_channels = 32
#
# 18:42:02 [I] launch:55            n_excerpts = 50
#
# 18:42:02 [I] launch:55            n_features_per_channel = 3
#
# 18:42:02 [I] launch:55            pca_n_waveforms_max = 10000
#
# 18:42:02 [I] launch:55            prb_file = /home/isabella/Documents/isabella/klusta_testdata/220624_sorting_1.5_4/probe.prb
#
# 18:42:02 [I] launch:55            raw_data_files = /home/isabella/Documents/isabella/klusta_testdata/220624_sorting_1.5_4/recording.dat
#
# 18:42:02 [I] launch:55            sample_rate = 48000.0
#
# 18:42:02 [I] launch:55            threshold_strong_std_factor = 4
#
# 18:42:02 [I] launch:55            threshold_weak_std_factor = 1.5
#
# 18:42:02 [I] launch:55            use_single_threshold = 1
#
# 18:42:02 [I] launch:55            voltage_gain = 1.0
#
# 18:42:02 [I] launch:55            weight_power = 2
#
# 18:42:02 [I] spikedetekt:212      Found 32 live channels in group 0.
#
# 18:42:02 [I] spikedetekt:285      Finding the thresholds...
#
#
#
# Detecting spikes        :   0%|          | 0/2312 [00:00<?, ?it/s]
#
# Detecting spikes        :   0%|          | 1/2312 [00:05<3:27:51,  5.40s/it]
#
# Detecting spikes        :   0%|          | 2/2312 [00:10<3:27:59,  5.40s/it]
#
# Detecting spikes        :   0%|          | 3/2312 [00:16<3:29:10,  5.44s/it]
#
# Detecting spikes        :   0%|          | 4/2312 [00:22<3:34:05,  5.57s/it]
#
# Detecting spikes        :   0%|          | 5/2312 [00:27<3:36:27,  5.63s/it]
#
# Detecting spikes        :   0%|          | 6/2312 [00:32<3:29:55,  5.46s/it]
#
# Detecting spikes        :   0%|          | 7/2312 [00:38<3:31:54,  5.52s/it]
#
# Detecting spikes        :   0%|          | 8/2312 [00:43<3:26:44,  5.38s/it]
#
# Detecting spikes        :   0%|          | 9/2312 [00:48<3:19:48,  5.21s/it]
#
# Detecting spikes        :   0%|          | 10/2312 [00:53<3:17:37,  5.15s/it]
#
# Detecting spikes        :   0%|          | 11/2312 [00:58<3:17:51,  5.16s/it]
#
# Detecting spikes        :   1%|          | 12/2312 [01:03<3:16:39,  5.13s/it]
#
# Detecting spikes        :   1%|          | 13/2312 [01:09<3:21:05,  5.25s/it]
#
# Detecting spikes        :   1%|          | 14/2312 [01:14<3:17:55,  5.17s/it]
#
# Detecting spikes        :   1%|          | 15/2312 [01:19<3:18:11,  5.18s/it]
#
# Detecting spikes        :   1%|          | 16/2312 [01:25<3:24:05,  5.33s/it]
#
# Detecting spikes        :   1%|          | 17/2312 [01:29<3:16:04,  5.13s/it]
#
# Detecting spikes        :   1%|          | 18/2312 [01:34<3:14:17,  5.08s/it]
#
# Detecting spikes        :   1%|          | 19/2312 [01:41<3:35:44,  5.65s/it]
#
# Detecting spikes        :   1%|          | 20/2312 [01:50<4:09:36,  6.53s/it]
#
# Detecting spikes        :   1%|          | 21/2312 [01:55<3:51:25,  6.06s/it]
#
# Detecting spikes        :   1%|          | 22/2312 [01:59<3:30:05,  5.50s/it]
#
# Detecting spikes        :   1%|          | 23/2312 [02:03<3:16:32,  5.15s/it]
#
# Detecting spikes        :   1%|          | 24/2312 [02:09<3:20:15,  5.25s/it]
#
# Detecting spikes        :   1%|          | 25/2312 [02:15<3:26:00,  5.40s/it]
#
# Detecting spikes        :   1%|          | 26/2312 [02:20<3:23:12,  5.33s/it]
#
# Detecting spikes        :   1%|          | 27/2312 [02:25<3:21:52,  5.30s/it]
#
# Detecting spikes        :   1%|          | 28/2312 [02:31<3:24:42,  5.38s/it]
#
# Detecting spikes        :   1%|▏         | 29/2312 [02:36<3:26:31,  5.43s/it]
#
# Detecting spikes        :   1%|▏         | 30/2312 [02:41<3:22:46,  5.33s/it]
#
# Detecting spikes        :   1%|▏         | 31/2312 [02:47<3:27:23,  5.46s/it]
#
# Detecting spikes        :   1%|▏         | 32/2312 [02:52<3:25:27,  5.41s/it]
#
# Detecting spikes        :   1%|▏         | 33/2312 [02:57<3:21:06,  5.29s/it]
#
# Detecting spikes        :   1%|▏         | 34/2312 [03:03<3:28:01,  5.48s/it]
#
# Detecting spikes        :   2%|▏         | 35/2312 [03:09<3:28:34,  5.50s/it]
#
# Detecting spikes        :   2%|▏         | 36/2312 [03:14<3:24:09,  5.38s/it]
#
# Detecting spikes        :   2%|▏         | 37/2312 [03:19<3:22:38,  5.34s/it]
#
# Detecting spikes        :   2%|▏         | 38/2312 [03:24<3:16:47,  5.19s/it]
#
# Detecting spikes        :   2%|▏         | 39/2312 [03:29<3:16:04,  5.18s/it]
#
# Detecting spikes        :   2%|▏         | 40/2312 [03:35<3:23:53,  5.38s/it]
#
# Detecting spikes        :   2%|▏         | 41/2312 [03:41<3:26:35,  5.46s/it]

# %%
#Run phy on klusta output
os.environ["QTWEBENGINE_CHROMIUM_FLAGS"] = "--single-process"

## If tetrodes sorted separately, change channel_group to choose tetrode to display in phy
phy.apps.kwik.kwik_gui(sorting_path/'recording.kwik', channel_group=None, clustering=None)
