# %% [markdown]
# # SpikeInterface Processing Pipeline for Tetrodes & Neuronexus Probe
# ### Jake Swann
#
# ##### This is a notebook which takes a spreadsheet as input with information on raw Axona recordings, and sorts all unsorted recordings in a loop. It will concatenate all recordings made on each unique day, and sort them all together, to be split apart afterwards
# ##### Each path in the spreadsheet should be to a folder containing raw Axona recordings (1 .set and 1 .bin file per recording)
# ##### The script loads them as a [SpikeInterface](https://github.com/SpikeInterface) object & attaches probe geometry, spike sorts using Klusta, and allows curation of the output in [phy](https://github.com/cortex-lab/phy/)
# ##### **N.B.** This requires a Python 3.7 environment with various dependencies installed, including Klusta version 0.95.0, SpikeInterface, and phy. There is code to install most of these from within the 'axona_spikeinterface.ipynb' notebook
# ---

# %% [markdown]
# #### Run axona_spikeinterface script on all recordings marked on a spreadsheet

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) #gets rid of some annoying warnings

# %%
import pandas as pd
import numpy as np
import spikeinterface as si
import spikeinterface.extractors as se
import spikeinterface.preprocessing as spre
from pathlib import Path
from utils import *
import os


# %matplotlib widget


sheet = pd.read_excel('tetrode_data_JS.xlsx')
# sheet = pd.read_excel('probe_data_IV.xlsx')
sorting_suffix = 'sorting_klusta_1.5_3.5'

sheet_inc = sheet[sheet['include_spikeinterface'] == 'Y']
trial_list = sheet_inc['trial_name']. to_list()
session_list = np.unique([i[:6] for i in trial_list])    

# Collect into sessions and preprocess
recording_list = []
for i,session in enumerate(session_list):
    recording_list.append([])
    for j in trial_list:
        if session in j:
            base_folder = sheet_inc[sheet_inc['trial_name'] == j]['path'].tolist()[0]
            num_channels = int(sheet_inc[sheet_inc['trial_name'] == j]['num_channels'].tolist()[0])
            electrode_type = sheet_inc[sheet_inc['trial_name'] == j]['probe_type'].tolist()[0]
            print(f"{base_folder}/{j}.set")
            recording = se.read_axona(f"{base_folder}/{j}.set")
            
            #Invert trace if recorded on -signal or ref-signal mode (mode 2 and 3)
            if int(get_mode(f"{base_folder}/{j}.set")) in [2,3]:
                recording = spre.scale(recording, gain=-1)
                print('Inverting recording trace')
            
            
            recording_list[i].append([preprocess(recording = recording,
                                     recording_name = j,
                                     base_folder = base_folder,
                                     electrode_type = electrode_type,
                                     num_channels = num_channels),
                                     j, base_folder, electrode_type])
                                     
                
# Concatenate over a single session and sort
recordings_concat = []
for i, recording in enumerate(recording_list):
    session = pd.DataFrame(recording_list[i])
    
    recordings_concat.append(si.concatenate_recordings(session.iloc[:,0]))
    for j, concat in enumerate(recordings_concat):
        print(f'Sorting {concat}')
        sorting = sort(recording = concat, 
             recording_name = session_list[j], 
             base_folder = session.iloc[0,2],
             electrode_type = session.iloc[0,3],
             sorting_suffix = sorting_suffix)
        session.to_csv(f'{base_folder}/{session_list[j]}_{sorting_suffix}/session.csv') #save session trial info to .csv

print(session)
# Out:
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/phy/utils/plugin.py:14: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/phy/plot/gloo/variable.py:86: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   gl.GL_BOOL: (1, gl.GL_BOOL, np.bool),
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/phy/plot/gloo/variable.py:87: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   gl.GL_BOOL_VEC2: (2, gl.GL_BOOL, np.bool),
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/phy/plot/gloo/variable.py:88: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   gl.GL_BOOL_VEC3: (3, gl.GL_BOOL, np.bool),
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/phy/plot/gloo/variable.py:89: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   gl.GL_BOOL_VEC4: (4, gl.GL_BOOL, np.bool),
# /home/isabella/Documents/isabella/jake/recording_data/201028b_famBox.set
# write_binary_recording with n_jobs = 1 and chunk_size = None
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/ipywidgets/widgets/widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/ipywidgets/widgets/widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/ipywidgets/widgets/widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/ipywidgets/widgets/widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# Recording preprocessed and saved
# /home/isabella/Documents/isabella/jake/recording_data/r1299/2023-01-24/230124_r1299_t-maze_2_raw.set
# /home/isabella/Documents/isabella/jake/recording_data/r1299/2023-01-24/230124_r1299_t-maze_2_raw_preprocessed
# 32-channel tetrode recording loaded from previous preprocessing
# BinaryFolderRecording: 32 channels - 1 segments - 48.0kHz - 600.006s
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/ipywidgets/widgets/widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/ipywidgets/widgets/widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/ipywidgets/widgets/widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/ipywidgets/widgets/widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# Sorting ConcatenateSegmentRecording: 64 channels - 1 segments - 48.0kHz - 600.062s
# write_binary_recording:   0%|          | 0/601 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/201028_sorting_klusta_1.5_3.5/run_klusta.sh
# 15:52:09 [I] creator:446          Using kwik file `/data/isabella/jake/recording_data/201028_sorting_klusta_1.5_3.5/recording.kwik`.
#
# 15:52:09 [I] launch:206           Starting spike detection.
#
# 15:52:09 [I] launch:53            SpikeDetekt parameters:
#
# 15:52:09 [I] launch:55            chunk_overlap_seconds = 0.015
#
# 15:52:09 [I] launch:55            chunk_size_seconds = 3
#
# 15:52:09 [I] launch:55            connected_component_join_size = 1
#
# 15:52:09 [I] launch:55            detect_spikes = negative
#
# 15:52:09 [I] launch:55            dtype = int16
#
# 15:52:09 [I] launch:55            excerpt_size_seconds = 1
#
# 15:52:09 [I] launch:55            experiment_name = recording.kwik
#
# 15:52:09 [I] launch:55            extract_s_after = 32
#
# 15:52:09 [I] launch:55            extract_s_before = 16
#
# 15:52:09 [I] launch:55            filter_butter_order = 3
#
# 15:52:09 [I] launch:55            filter_high_factor = 0.475
#
# 15:52:09 [I] launch:55            filter_low = 500.0
#
# 15:52:09 [I] launch:55            n_channels = 64
#
# 15:52:09 [I] launch:55            n_excerpts = 50
#
# 15:52:09 [I] launch:55            n_features_per_channel = 3
#
# 15:52:09 [I] launch:55            pca_n_waveforms_max = 10000
#
# 15:52:09 [I] launch:55            prb_file = /home/isabella/Documents/isabella/jake/recording_data/201028_sorting_klusta_1.5_3.5/probe.prb
#
# 15:52:09 [I] launch:55            raw_data_files = /home/isabella/Documents/isabella/jake/recording_data/201028_sorting_klusta_1.5_3.5/recording.dat
#
# 15:52:09 [I] launch:55            sample_rate = 48000.0
#
# 15:52:09 [I] launch:55            threshold_strong_std_factor = 3.5
#
# 15:52:09 [I] launch:55            threshold_weak_std_factor = 1.5
#
# 15:52:09 [I] launch:55            use_single_threshold = 1
#
# 15:52:09 [I] launch:55            voltage_gain = 1.0
#
# 15:52:09 [I] launch:55            weight_power = 2
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 0.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 1.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 2.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 3.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 4.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 5.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 6.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 7.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 8.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 9.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 10.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 11.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 12.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 13.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 14.
#
# 15:52:09 [I] spikedetekt:212      Found 4 live channels in group 15.
#
# 15:52:09 [I] spikedetekt:285      Finding the thresholds...
#
#
#
# Detecting spikes        :   0%|          | 0/202 [00:00<?, ?it/s]
#
# Detecting spikes        :   0%|          | 1/202 [00:10<34:07, 10.19s/it]
#
# Detecting spikes        :   1%|          | 2/202 [00:19<32:33,  9.77s/it]
#
# Detecting spikes        :   1%|▏         | 3/202 [00:29<32:09,  9.70s/it]
#
# Detecting spikes        :   2%|▏         | 4/202 [00:39<32:09,  9.75s/it]
#
# Detecting spikes        :   2%|▏         | 5/202 [00:49<32:25,  9.87s/it]
#
# Detecting spikes        :   3%|▎         | 6/202 [00:59<32:56, 10.08s/it]
#
# Detecting spikes        :   3%|▎         | 7/202 [01:10<33:52, 10.42s/it]
#
# Detecting spikes        :   4%|▍         | 8/202 [01:20<33:22, 10.32s/it]
#
# Detecting spikes        :   4%|▍         | 9/202 [01:31<33:05, 10.29s/it]
#
# Detecting spikes        :   5%|▍         | 10/202 [01:43<34:42, 10.85s/it]
#
# Detecting spikes        :   5%|▌         | 11/202 [01:54<34:55, 10.97s/it]
#
# Detecting spikes        :   6%|▌         | 12/202 [02:05<34:22, 10.85s/it]
#
# Detecting spikes        :   6%|▋         | 13/202 [02:15<34:15, 10.88s/it]
#
# Detecting spikes        :   7%|▋         | 14/202 [02:27<34:19, 10.95s/it]
#
# Detecting spikes        :   7%|▋         | 15/202 [02:37<33:25, 10.72s/it]
#
# Detecting spikes        :   8%|▊         | 16/202 [02:47<32:52, 10.60s/it]
#
# Detecting spikes        :   8%|▊         | 17/202 [02:58<32:49, 10.65s/it]
#
# Detecting spikes        :   9%|▉         | 18/202 [03:08<32:35, 10.63s/it]
#
# Detecting spikes        :   9%|▉         | 19/202 [03:19<32:43, 10.73s/it]
#
# Detecting spikes        :  10%|▉         | 20/202 [03:30<32:17, 10.65s/it]
#
# Detecting spikes        :  10%|█         | 21/202 [03:40<31:36, 10.48s/it]
#
# Detecting spikes        :  11%|█         | 22/202 [03:50<30:44, 10.25s/it]
#
# Detecting spikes        :  11%|█▏        | 23/202 [04:00<30:13, 10.13s/it]
#
# Detecting spikes        :  12%|█▏        | 24/202 [04:11<31:20, 10.56s/it]
#
# Detecting spikes        :  12%|█▏        | 25/202 [04:23<31:56, 10.83s/it]
#
# Detecting spikes        :  13%|█▎        | 26/202 [04:34<32:12, 10.98s/it]
#
# Detecting spikes        :  13%|█▎        | 27/202 [04:45<31:47, 10.90s/it]
#
# Detecting spikes        :  14%|█▍        | 28/202 [04:55<31:18, 10.80s/it]
#
# Detecting spikes        :  14%|█▍        | 29/202 [05:06<31:01, 10.76s/it]
#
# Detecting spikes        :  15%|█▍        | 30/202 [05:16<30:35, 10.67s/it]
#
# Detecting spikes        :  15%|█▌        | 31/202 [05:26<29:54, 10.49s/it]
#
# Detecting spikes        :  16%|█▌        | 32/202 [05:37<29:30, 10.42s/it]
#
# Detecting spikes        :  16%|█▋        | 33/202 [05:48<30:00, 10.66s/it]
#
# Detecting spikes        :  17%|█▋        | 34/202 [05:59<30:08, 10.76s/it]
#
# Detecting spikes        :  17%|█▋        | 35/202 [06:10<30:23, 10.92s/it]
#
# Detecting spikes        :  18%|█▊        | 36/202 [06:20<29:41, 10.73s/it]
#
# Detecting spikes        :  18%|█▊        | 37/202 [06:31<29:07, 10.59s/it]
#
# Detecting spikes        :  19%|█▉        | 38/202 [06:41<28:50, 10.55s/it]
#
# Detecting spikes        :  19%|█▉        | 39/202 [06:52<28:58, 10.66s/it]
#
# Detecting spikes        :  20%|█▉        | 40/202 [07:03<28:54, 10.71s/it]
#
# Detecting spikes        :  20%|██        | 41/202 [07:14<28:48, 10.74s/it]
#
# Detecting spikes        :  21%|██        | 42/202 [07:25<28:45, 10.79s/it]
#
# Detecting spikes        :  21%|██▏       | 43/202 [07:36<28:41, 10.83s/it]
#
# Detecting spikes        :  22%|██▏       | 44/202 [07:47<29:06, 11.05s/it]
#
# Detecting spikes        :  22%|██▏       | 45/202 [07:58<28:47, 11.00s/it]
#
# Detecting spikes        :  23%|██▎       | 46/202 [08:08<28:11, 10.84s/it]
#
# Detecting spikes        :  23%|██▎       | 47/202 [08:19<27:37, 10.69s/it]
#
# Detecting spikes        :  24%|██▍       | 48/202 [08:30<27:44, 10.81s/it]
#
# Detecting spikes        :  24%|██▍       | 49/202 [08:42<28:17, 11.09s/it]
#
# Detecting spikes        :  25%|██▍       | 50/202 [08:52<27:40, 10.92s/it]
#
# Detecting spikes        :  25%|██▌       | 51/202 [09:02<26:51, 10.67s/it]
#
# Detecting spikes        :  26%|██▌       | 52/202 [09:13<26:26, 10.58s/it]
#
# Detecting spikes        :  26%|██▌       | 53/202 [09:24<26:44, 10.77s/it]
#
# Detecting spikes        :  27%|██▋       | 54/202 [09:34<26:25, 10.72s/it]
#
# Detecting spikes        :  27%|██▋       | 55/202 [09:45<26:02, 10.63s/it]
#
# Detecting spikes        :  28%|██▊       | 56/202 [09:56<25:54, 10.65s/it]
#
# Detecting spikes        :  28%|██▊       | 57/202 [10:07<26:00, 10.76s/it]
#
# Detecting spikes        :  29%|██▊       | 58/202 [10:18<26:00, 10.84s/it]
#
# Detecting spikes        :  29%|██▉       | 59/202 [10:29<26:02, 10.92s/it]
#
# Detecting spikes        :  30%|██▉       | 60/202 [10:39<25:30, 10.78s/it]
#
# Detecting spikes        :  30%|███       | 61/202 [10:49<24:56, 10.61s/it]
#
# Detecting spikes        :  31%|███       | 62/202 [11:00<24:35, 10.54s/it]
#
# Detecting spikes        :  31%|███       | 63/202 [11:10<24:30, 10.58s/it]
#
# Detecting spikes        :  32%|███▏      | 64/202 [11:21<24:21, 10.59s/it]
#
# Detecting spikes        :  32%|███▏      | 65/202 [11:33<25:11, 11.03s/it]
#
# Detecting spikes        :  33%|███▎      | 66/202 [11:45<25:16, 11.15s/it]
# Detecting spikes        :  33%|███▎      | 67/202 [11:56<25:05, 11.15s/it]
#
# Detecting spikes        :  34%|███▎      | 68/202 [12:06<24:34, 11.00s/it]
#
# Detecting spikes        :  34%|███▍      | 69/202 [12:17<24:25, 11.02s/it]
#
# Detecting spikes        :  35%|███▍      | 70/202 [12:28<23:53, 10.86s/it]
#
# Detecting spikes        :  35%|███▌      | 71/202 [12:38<23:15, 10.65s/it]
#
# Detecting spikes        :  36%|███▌      | 72/202 [12:49<23:02, 10.64s/it]
#
# Detecting spikes        :  36%|███▌      | 73/202 [12:59<23:01, 10.71s/it]
#
# Detecting spikes        :  37%|███▋      | 74/202 [13:10<22:42, 10.64s/it]
#
# Detecting spikes        :  37%|███▋      | 75/202 [13:21<22:45, 10.75s/it]
#
# Detecting spikes        :  38%|███▊      | 76/202 [13:32<22:30, 10.72s/it]
#
# Detecting spikes        :  38%|███▊      | 77/202 [13:43<22:31, 10.81s/it]
#
# Detecting spikes        :  39%|███▊      | 78/202 [13:54<22:24, 10.84s/it]
#
# Detecting spikes        :  39%|███▉      | 79/202 [14:04<22:07, 10.80s/it]
#
# Detecting spikes        :  40%|███▉      | 80/202 [14:15<21:42, 10.68s/it]
#
# Detecting spikes        :  40%|████      | 81/202 [14:25<21:34, 10.70s/it]
#
# Detecting spikes        :  41%|████      | 82/202 [14:35<20:55, 10.46s/it]
#
# Detecting spikes        :  41%|████      | 83/202 [14:45<20:26, 10.31s/it]
#
# Detecting spikes        :  42%|████▏     | 84/202 [14:56<20:31, 10.44s/it]
#
# Detecting spikes        :  42%|████▏     | 85/202 [15:07<20:29, 10.51s/it]
#
# Detecting spikes        :  43%|████▎     | 86/202 [15:17<20:21, 10.53s/it]
#
# Detecting spikes        :  43%|████▎     | 87/202 [15:28<20:00, 10.44s/it]
#
# Detecting spikes        :  44%|████▎     | 88/202 [15:37<19:26, 10.23s/it]
#
# Detecting spikes        :  44%|████▍     | 89/202 [15:47<19:00, 10.10s/it]
#
# Detecting spikes        :  45%|████▍     | 90/202 [15:58<19:06, 10.24s/it]
#
# Detecting spikes        :  45%|████▌     | 91/202 [16:08<18:56, 10.24s/it]
#
# Detecting spikes        :  46%|████▌     | 92/202 [16:18<18:35, 10.14s/it]
#
# Detecting spikes        :  46%|████▌     | 93/202 [16:28<18:42, 10.30s/it]
#
# Detecting spikes        :  47%|████▋     | 94/202 [16:38<18:22, 10.20s/it]
#
# Detecting spikes        :  47%|████▋     | 95/202 [16:49<18:22, 10.31s/it]
#
# Detecting spikes        :  48%|████▊     | 96/202 [17:00<18:22, 10.40s/it]
#
# Detecting spikes        :  48%|████▊     | 97/202 [17:10<18:21, 10.49s/it]
#
# Detecting spikes        :  49%|████▊     | 98/202 [17:21<18:16, 10.54s/it]
#
# Detecting spikes        :  49%|████▉     | 99/202 [17:32<18:08, 10.57s/it]
#
# Detecting spikes        :  50%|████▉     | 100/202 [17:42<17:59, 10.59s/it]
#
# Detecting spikes        :  50%|█████     | 101/202 [17:54<18:11, 10.81s/it]
#
# Detecting spikes        :  50%|█████     | 102/202 [18:05<18:06, 10.87s/it]
#
# Detecting spikes        :  51%|█████     | 103/202 [18:16<18:05, 10.97s/it]
#
# Detecting spikes        :  51%|█████▏    | 104/202 [18:27<17:53, 10.96s/it]
#
# Detecting spikes        :  52%|█████▏    | 105/202 [18:37<17:29, 10.82s/it]
#
# Detecting spikes        :  52%|█████▏    | 106/202 [18:47<16:51, 10.54s/it]
#
# Detecting spikes        :  53%|█████▎    | 107/202 [18:57<16:28, 10.41s/it]
#
# Detecting spikes        :  53%|█████▎    | 108/202 [19:07<16:08, 10.30s/it]
#
# Detecting spikes        :  54%|█████▍    | 109/202 [19:17<15:56, 10.29s/it]
#
# Detecting spikes        :  54%|█████▍    | 110/202 [19:29<16:21, 10.67s/it]
#
# Detecting spikes        :  55%|█████▍    | 111/202 [19:40<16:22, 10.80s/it]
#
# Detecting spikes        :  55%|█████▌    | 112/202 [19:51<16:18, 10.87s/it]
#
# Detecting spikes        :  56%|█████▌    | 113/202 [20:02<16:03, 10.83s/it]
#
# Detecting spikes        :  56%|█████▋    | 114/202 [20:12<15:33, 10.61s/it]
#
# Detecting spikes        :  57%|█████▋    | 115/202 [20:22<15:11, 10.48s/it]
#
# Detecting spikes        :  57%|█████▋    | 116/202 [20:33<15:09, 10.58s/it]
#
# Detecting spikes        :  58%|█████▊    | 117/202 [20:43<14:57, 10.56s/it]
#
# Detecting spikes        :  58%|█████▊    | 118/202 [20:55<15:10, 10.83s/it]
#
# Detecting spikes        :  59%|█████▉    | 119/202 [21:06<14:57, 10.82s/it]
#
# Detecting spikes        :  59%|█████▉    | 120/202 [21:16<14:26, 10.56s/it]
#
# Detecting spikes        :  60%|█████▉    | 121/202 [21:25<13:54, 10.30s/it]
#
# Detecting spikes        :  60%|██████    | 122/202 [21:35<13:35, 10.20s/it]
#
# Detecting spikes        :  61%|██████    | 123/202 [21:45<13:18, 10.11s/it]
#
# Detecting spikes        :  61%|██████▏   | 124/202 [21:55<13:03, 10.04s/it]
#
# Detecting spikes        :  62%|██████▏   | 125/202 [22:05<12:52, 10.03s/it]
#
# Detecting spikes        :  62%|██████▏   | 126/202 [22:15<12:37,  9.96s/it]
#
# Detecting spikes        :  63%|██████▎   | 127/202 [22:25<12:27,  9.96s/it]
#
# Detecting spikes        :  63%|██████▎   | 128/202 [22:35<12:26, 10.09s/it]
#
# Detecting spikes        :  64%|██████▍   | 129/202 [22:45<12:18, 10.11s/it]
#
# Detecting spikes        :  64%|██████▍   | 130/202 [22:56<12:24, 10.35s/it]
#
# Detecting spikes        :  65%|██████▍   | 131/202 [23:07<12:26, 10.51s/it]
#
# Detecting spikes        :  65%|██████▌   | 132/202 [23:18<12:17, 10.54s/it]
#
# Detecting spikes        :  66%|██████▌   | 133/202 [23:28<12:08, 10.56s/it]
#
# Detecting spikes        :  66%|██████▋   | 134/202 [23:39<11:59, 10.59s/it]
#
# Detecting spikes        :  67%|██████▋   | 135/202 [23:50<12:00, 10.75s/it]
#
# Detecting spikes        :  67%|██████▋   | 136/202 [24:01<11:43, 10.67s/it]
#
# Detecting spikes        :  68%|██████▊   | 137/202 [24:11<11:33, 10.66s/it]
#
# Detecting spikes        :  68%|██████▊   | 138/202 [24:22<11:21, 10.64s/it]
#
# Detecting spikes        :  69%|██████▉   | 139/202 [24:32<11:02, 10.52s/it]
#
# Detecting spikes        :  69%|██████▉   | 140/202 [24:43<10:57, 10.60s/it]
#
# Detecting spikes        :  70%|██████▉   | 141/202 [24:53<10:41, 10.52s/it]
#
# Detecting spikes        :  70%|███████   | 142/202 [25:03<10:24, 10.41s/it]
#
# Detecting spikes        :  71%|███████   | 143/202 [25:13<10:02, 10.20s/it]
#
# Detecting spikes        :  71%|███████▏  | 144/202 [25:23<09:44, 10.07s/it]
#
# Detecting spikes        :  72%|███████▏  | 145/202 [25:33<09:33, 10.06s/it]
#
# Detecting spikes        :  72%|███████▏  | 146/202 [25:44<09:33, 10.25s/it]
#
# Detecting spikes        :  73%|███████▎  | 147/202 [25:53<09:16, 10.12s/it]
#
# Detecting spikes        :  73%|███████▎  | 148/202 [26:04<09:07, 10.15s/it]
#
# Detecting spikes        :  74%|███████▍  | 149/202 [26:14<08:58, 10.17s/it]
#
# Detecting spikes        :  74%|███████▍  | 150/202 [26:24<08:50, 10.20s/it]
#
# Detecting spikes        :  75%|███████▍  | 151/202 [26:34<08:40, 10.21s/it]
#
# Detecting spikes        :  75%|███████▌  | 152/202 [26:44<08:26, 10.14s/it]
#
# Detecting spikes        :  76%|███████▌  | 153/202 [26:55<08:28, 10.37s/it]
#
# Detecting spikes        :  76%|███████▌  | 154/202 [27:07<08:30, 10.64s/it]
#
# Detecting spikes        :  77%|███████▋  | 155/202 [27:17<08:18, 10.62s/it]
#
# Detecting spikes        :  77%|███████▋  | 156/202 [27:28<08:06, 10.58s/it]
#
# Detecting spikes        :  78%|███████▊  | 157/202 [27:38<07:54, 10.54s/it]
#
# Detecting spikes        :  78%|███████▊  | 158/202 [27:48<07:42, 10.50s/it]
#
# Detecting spikes        :  79%|███████▊  | 159/202 [27:59<07:31, 10.51s/it]
#
# Detecting spikes        :  79%|███████▉  | 160/202 [28:10<07:31, 10.76s/it]
#
# Detecting spikes        :  80%|███████▉  | 161/202 [28:22<07:27, 10.92s/it]
#
# Detecting spikes        :  80%|████████  | 162/202 [28:33<07:17, 10.93s/it]
#
# Detecting spikes        :  81%|████████  | 163/202 [28:43<07:00, 10.79s/it]
#
# Detecting spikes        :  81%|████████  | 164/202 [28:53<06:39, 10.51s/it]
#
# Detecting spikes        :  82%|████████▏ | 165/202 [29:03<06:20, 10.29s/it]
#
# Detecting spikes        :  82%|████████▏ | 166/202 [29:13<06:14, 10.41s/it]
#
# Detecting spikes        :  83%|████████▎ | 167/202 [29:24<06:04, 10.41s/it]
#
# Detecting spikes        :  83%|████████▎ | 168/202 [29:34<05:51, 10.33s/it]
#
# Detecting spikes        :  84%|████████▎ | 169/202 [29:45<05:43, 10.41s/it]
#
# Detecting spikes        :  84%|████████▍ | 170/202 [29:55<05:36, 10.53s/it]
#
# Detecting spikes        :  85%|████████▍ | 171/202 [30:07<05:35, 10.82s/it]
#
# Detecting spikes        :  85%|████████▌ | 172/202 [30:18<05:26, 10.88s/it]
#
# Detecting spikes        :  86%|████████▌ | 173/202 [30:30<05:23, 11.17s/it]
# Detecting spikes        :  86%|████████▌ | 174/202 [30:42<05:23, 11.54s/it]
#
# Detecting spikes        :  87%|████████▋ | 175/202 [30:53<05:08, 11.43s/it]
#
# Detecting spikes        :  87%|████████▋ | 176/202 [31:05<04:55, 11.38s/it]
#
# Detecting spikes        :  88%|████████▊ | 177/202 [31:16<04:42, 11.29s/it]
#
# Detecting spikes        :  88%|████████▊ | 178/202 [31:27<04:33, 11.39s/it]
#
# Detecting spikes        :  89%|████████▊ | 179/202 [31:38<04:20, 11.32s/it]
#
# Detecting spikes        :  89%|████████▉ | 180/202 [31:50<04:07, 11.26s/it]
#
# Detecting spikes        :  90%|████████▉ | 181/202 [32:01<03:56, 11.24s/it]
#
# Detecting spikes        :  90%|█████████ | 182/202 [32:11<03:41, 11.07s/it]
#
# Detecting spikes        :  91%|█████████ | 183/202 [32:22<03:28, 10.96s/it]
#
# Detecting spikes        :  91%|█████████ | 184/202 [32:33<03:18, 11.03s/it]
#
# Detecting spikes        :  92%|█████████▏| 185/202 [32:44<03:04, 10.85s/it]
#
# Detecting spikes        :  92%|█████████▏| 186/202 [32:55<02:53, 10.85s/it]
#
# Detecting spikes        :  93%|█████████▎| 187/202 [33:06<02:46, 11.09s/it]
#
# Detecting spikes        :  93%|█████████▎| 188/202 [33:17<02:33, 10.97s/it]
#
# Detecting spikes        :  94%|█████████▎| 189/202 [33:28<02:21, 10.87s/it]
#
# Detecting spikes        :  94%|█████████▍| 190/202 [33:38<02:09, 10.76s/it]
#
# Detecting spikes        :  95%|█████████▍| 191/202 [33:48<01:55, 10.52s/it]
#
# Detecting spikes        :  95%|█████████▌| 192/202 [33:58<01:44, 10.44s/it]
#
# Detecting spikes        :  96%|█████████▌| 193/202 [34:08<01:32, 10.28s/it]
#
# Detecting spikes        :  96%|█████████▌| 194/202 [34:18<01:21, 10.14s/it]
#
# Detecting spikes        :  97%|█████████▋| 195/202 [34:28<01:11, 10.20s/it]
#
# Detecting spikes        :  97%|█████████▋| 196/202 [34:39<01:02, 10.46s/it]
#
# Detecting spikes        :  98%|█████████▊| 197/202 [34:50<00:52, 10.49s/it]
#
# Detecting spikes        :  98%|█████████▊| 198/202 [35:00<00:41, 10.28s/it]
#
# Detecting spikes        :  99%|█████████▊| 199/202 [35:10<00:31, 10.36s/it]
#
# Detecting spikes        :  99%|█████████▉| 200/202 [35:20<00:20, 10.32s/it]
#
# Detecting spikes        : 100%|█████████▉| 201/202 [35:32<00:10, 10.68s/it]
#
# Detecting spikes        : 100%|██████████| 202/202 [35:32<00:00,  7.56s/it]
#
# Detecting spikes        : 100%|██████████| 202/202 [35:32<00:00, 10.56s/it]
#
#
#
# Extracting waveforms    :   0%|          | 0/202 [00:00<?, ?it/s]
#
# Extracting waveforms    :   1%|          | 2/202 [00:00<00:18, 11.09it/s]
#
# Extracting waveforms    :   2%|▏         | 4/202 [00:00<00:17, 11.17it/s]
#
# Extracting waveforms    :   3%|▎         | 6/202 [00:00<00:17, 11.11it/s]
#
# Extracting waveforms    :   4%|▍         | 8/202 [00:00<00:17, 10.96it/s]
#
# Extracting waveforms    :   5%|▍         | 10/202 [00:00<00:17, 10.80it/s]
#
# Extracting waveforms    :   6%|▌         | 12/202 [00:01<00:17, 10.76it/s]
#
# Extracting waveforms    :   7%|▋         | 14/202 [00:01<00:17, 10.76it/s]
#
# Extracting waveforms    :   8%|▊         | 16/202 [00:01<00:17, 10.80it/s]
#
# Extracting waveforms    :   9%|▉         | 18/202 [00:01<00:17, 10.82it/s]
#
# Extracting waveforms    :  10%|▉         | 20/202 [00:01<00:16, 10.77it/s]
#
# Extracting waveforms    :  11%|█         | 22/202 [00:02<00:16, 10.59it/s]
#
# Extracting waveforms    :  12%|█▏        | 24/202 [00:02<00:16, 10.68it/s]
#
# Extracting waveforms    :  13%|█▎        | 26/202 [00:02<00:16, 10.62it/s]
#
# Extracting waveforms    :  14%|█▍        | 28/202 [00:02<00:16, 10.66it/s]
#
# Extracting waveforms    :  15%|█▍        | 30/202 [00:02<00:16, 10.70it/s]
#
# Extracting waveforms    :  16%|█▌        | 32/202 [00:02<00:15, 10.81it/s]
#
# Extracting waveforms    :  17%|█▋        | 34/202 [00:03<00:15, 10.82it/s]
#
# Extracting waveforms    :  18%|█▊        | 36/202 [00:03<00:15, 10.72it/s]
#
# Extracting waveforms    :  19%|█▉        | 38/202 [00:03<00:15, 10.72it/s]
#
# Extracting waveforms    :  20%|█▉        | 40/202 [00:03<00:15, 10.77it/s]
#
# Extracting waveforms    :  21%|██        | 42/202 [00:03<00:14, 10.81it/s]
#
# Extracting waveforms    :  22%|██▏       | 44/202 [00:04<00:14, 10.72it/s]
#
# Extracting waveforms    :  23%|██▎       | 46/202 [00:04<00:14, 10.80it/s]
#
# Extracting waveforms    :  24%|██▍       | 48/202 [00:04<00:14, 10.87it/s]
#
# Extracting waveforms    :  25%|██▍       | 50/202 [00:04<00:14, 10.83it/s]
#
# Extracting waveforms    :  26%|██▌       | 52/202 [00:04<00:13, 10.87it/s]
#
# Extracting waveforms    :  27%|██▋       | 54/202 [00:05<00:13, 10.66it/s]
#
# Extracting waveforms    :  28%|██▊       | 56/202 [00:05<00:13, 10.78it/s]
#
# Extracting waveforms    :  29%|██▊       | 58/202 [00:05<00:13, 10.77it/s]
#
# Extracting waveforms    :  30%|██▉       | 60/202 [00:05<00:13, 10.77it/s]
#
# Extracting waveforms    :  31%|███       | 62/202 [00:05<00:13, 10.52it/s]
#
# Extracting waveforms    :  32%|███▏      | 64/202 [00:05<00:13, 10.60it/s]
#
# Extracting waveforms    :  33%|███▎      | 66/202 [00:06<00:12, 10.54it/s]
#
# Extracting waveforms    :  34%|███▎      | 68/202 [00:06<00:12, 10.66it/s]
#
# Extracting waveforms    :  35%|███▍      | 70/202 [00:06<00:12, 10.67it/s]
#
# Extracting waveforms    :  36%|███▌      | 72/202 [00:06<00:12, 10.77it/s]
#
# Extracting waveforms    :  37%|███▋      | 74/202 [00:06<00:11, 10.79it/s]
#
# Extracting waveforms    :  38%|███▊      | 76/202 [00:07<00:11, 10.81it/s]
#
# Extracting waveforms    :  39%|███▊      | 78/202 [00:07<00:11, 10.80it/s]
#
# Extracting waveforms    :  40%|███▉      | 80/202 [00:07<00:11, 10.91it/s]
#
# Extracting waveforms    :  41%|████      | 82/202 [00:07<00:10, 10.95it/s]
#
# Extracting waveforms    :  42%|████▏     | 84/202 [00:07<00:10, 11.03it/s]
#
# Extracting waveforms    :  43%|████▎     | 86/202 [00:07<00:10, 11.02it/s]
#
# Extracting waveforms    :  44%|████▎     | 88/202 [00:08<00:10, 11.09it/s]
#
# Extracting waveforms    :  45%|████▍     | 90/202 [00:08<00:10, 11.05it/s]
#
# Extracting waveforms    :  46%|████▌     | 92/202 [00:08<00:09, 11.10it/s]
#
# Extracting waveforms    :  47%|████▋     | 94/202 [00:08<00:09, 11.09it/s]
#
# Extracting waveforms    :  48%|████▊     | 96/202 [00:08<00:09, 11.12it/s]
#
# Extracting waveforms    :  49%|████▊     | 98/202 [00:09<00:09, 11.10it/s]
#
# Extracting waveforms    :  50%|████▉     | 100/202 [00:09<00:09, 11.16it/s]
#
# Extracting waveforms    :  50%|█████     | 102/202 [00:09<00:08, 11.12it/s]
#
# Extracting waveforms    :  51%|█████▏    | 104/202 [00:09<00:08, 11.03it/s]
#
# Extracting waveforms    :  52%|█████▏    | 106/202 [00:09<00:08, 11.11it/s]
#
# Extracting waveforms    :  53%|█████▎    | 108/202 [00:09<00:08, 11.09it/s]
#
# Extracting waveforms    :  54%|█████▍    | 110/202 [00:10<00:08, 11.06it/s]
#
# Extracting waveforms    :  55%|█████▌    | 112/202 [00:10<00:08, 10.76it/s]
#
# Extracting waveforms    :  56%|█████▋    | 114/202 [00:10<00:08, 10.82it/s]
#
# Extracting waveforms    :  57%|█████▋    | 116/202 [00:10<00:07, 10.84it/s]
#
# Extracting waveforms    :  58%|█████▊    | 118/202 [00:10<00:07, 10.82it/s]
#
# Extracting waveforms    :  59%|█████▉    | 120/202 [00:11<00:07, 10.88it/s]
#
# Extracting waveforms    :  60%|██████    | 122/202 [00:11<00:07, 11.00it/s]
#
# Extracting waveforms    :  61%|██████▏   | 124/202 [00:11<00:07, 11.08it/s]
#
# Extracting waveforms    :  62%|██████▏   | 126/202 [00:11<00:06, 11.12it/s]
#
# Extracting waveforms    :  63%|██████▎   | 128/202 [00:11<00:06, 11.15it/s]
#
# Extracting waveforms    :  64%|██████▍   | 130/202 [00:11<00:06, 11.12it/s]
#
# Extracting waveforms    :  65%|██████▌   | 132/202 [00:12<00:06, 10.98it/s]
#
# Extracting waveforms    :  66%|██████▋   | 134/202 [00:12<00:06, 11.02it/s]
#
# Extracting waveforms    :  67%|██████▋   | 136/202 [00:12<00:06, 10.98it/s]
#
# Extracting waveforms    :  68%|██████▊   | 138/202 [00:12<00:05, 11.01it/s]
#
# Extracting waveforms    :  69%|██████▉   | 140/202 [00:12<00:05, 11.02it/s]
#
# Extracting waveforms    :  70%|███████   | 142/202 [00:13<00:05, 11.03it/s]
#
# Extracting waveforms    :  71%|███████▏  | 144/202 [00:13<00:05, 11.16it/s]
#
# Extracting waveforms    :  72%|███████▏  | 146/202 [00:13<00:05, 11.11it/s]
#
# Extracting waveforms    :  73%|███████▎  | 148/202 [00:13<00:04, 11.07it/s]
#
# Extracting waveforms    :  74%|███████▍  | 150/202 [00:13<00:04, 11.15it/s]
#
# Extracting waveforms    :  75%|███████▌  | 152/202 [00:13<00:04, 11.20it/s]
#
# Extracting waveforms    :  76%|███████▌  | 154/202 [00:14<00:04, 11.12it/s]
#
# Extracting waveforms    :  77%|███████▋  | 156/202 [00:14<00:04, 11.08it/s]
# Extracting waveforms    :  78%|███████▊  | 158/202 [00:14<00:03, 11.08it/s]
#
# Extracting waveforms    :  79%|███████▉  | 160/202 [00:14<00:03, 10.82it/s]
#
# Extracting waveforms    :  80%|████████  | 162/202 [00:14<00:03, 10.84it/s]
#
# Extracting waveforms    :  81%|████████  | 164/202 [00:15<00:03, 10.96it/s]
#
# Extracting waveforms    :  82%|████████▏ | 166/202 [00:15<00:03, 11.01it/s]
#
# Extracting waveforms    :  83%|████████▎ | 168/202 [00:15<00:03, 11.05it/s]
#
# Extracting waveforms    :  84%|████████▍ | 170/202 [00:15<00:02, 10.97it/s]
#
# Extracting waveforms    :  85%|████████▌ | 172/202 [00:15<00:02, 10.91it/s]
#
# Extracting waveforms    :  86%|████████▌ | 174/202 [00:15<00:02, 10.66it/s]
#
# Extracting waveforms    :  87%|████████▋ | 176/202 [00:16<00:02, 10.58it/s]
#
# Extracting waveforms    :  88%|████████▊ | 178/202 [00:16<00:02, 10.57it/s]
#
# Extracting waveforms    :  89%|████████▉ | 180/202 [00:16<00:02, 10.60it/s]
#
# Extracting waveforms    :  90%|█████████ | 182/202 [00:16<00:01, 10.66it/s]
#
# Extracting waveforms    :  91%|█████████ | 184/202 [00:16<00:01, 10.56it/s]
#
# Extracting waveforms    :  92%|█████████▏| 186/202 [00:17<00:01, 10.65it/s]
#
# Extracting waveforms    :  93%|█████████▎| 188/202 [00:17<00:01, 10.65it/s]
#
# Extracting waveforms    :  94%|█████████▍| 190/202 [00:17<00:01, 10.77it/s]
#
# Extracting waveforms    :  95%|█████████▌| 192/202 [00:17<00:00, 10.84it/s]
#
# Extracting waveforms    :  96%|█████████▌| 194/202 [00:17<00:00, 10.91it/s]
#
# Extracting waveforms    :  97%|█████████▋| 196/202 [00:18<00:00, 10.96it/s]
#
# Extracting waveforms    :  98%|█████████▊| 198/202 [00:18<00:00, 11.07it/s]
#
# Extracting waveforms    :  99%|█████████▉| 200/202 [00:18<00:00, 11.04it/s]
#
# Extracting waveforms    : 100%|██████████| 202/202 [00:18<00:00, 10.94it/s]
#
#
#
# Performing PCA          :   0%|          | 0/16 [00:00<?, ?it/s]
#
# Performing PCA          : 100%|██████████| 16/16 [00:00<00:00, 277.13it/s]
#
#
#
# Computing features      :   0%|          | 0/202 [00:00<?, ?it/s]
#
# Computing features      :   0%|          | 1/202 [00:12<40:58, 12.23s/it]
#
# Computing features      :   1%|          | 2/202 [00:25<41:56, 12.58s/it]
#
# Computing features      :   1%|▏         | 3/202 [00:37<41:42, 12.58s/it]
#
# Computing features      :   2%|▏         | 4/202 [00:50<41:19, 12.52s/it]
#
# Computing features      :   2%|▏         | 5/202 [01:02<40:57, 12.48s/it]
#
# Computing features      :   3%|▎         | 6/202 [01:15<41:02, 12.56s/it]

# %%
#Run phy on klusta output
from phy.apps.kwik import kwik_gui
os.environ["QTWEBENGINE_CHROMIUM_FLAGS"] = "--single-process"

## If tetrodes sorted separately, change channel_group to choose tetrode to display 
phykwik_gui(f'{base_folder}/{session_list[0]}_{sorting_suffix}/recording.kwik', channel_group=None, clustering=None)

# from phy.apps.template import template_gui
# template_gui(f'{base_folder}/{session_list[0]}_{sorting_suffix}/params.py')

# %% [markdown]
# ##### Misc utils

# %%
# import spikeinterface.sorters as ss
# ss.available_sorters()
#ss.installed_sorters()
# ss.get_sorter_params_description('klusta')

from phy.apps.kwik import kwik_gui
phy.apps.kwik.kwik_gui('/home/isabella/Documents/isabella/klusta_testdata/220624_sorting_klusta_2_5/recording.kwik',
                       channel_group=0, clustering=None)
