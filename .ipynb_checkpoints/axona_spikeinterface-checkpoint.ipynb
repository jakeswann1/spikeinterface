# %% [markdown]
# # SpikeInterface Processing Pipeline for Tetrodes & Neuronexus Probe
# ### Jake Swann
#
# ##### This is a notebook which takes raw Axona recordings (1 .set and 1 .bin file per recording), loads them as a [SpikeInterface](https://github.com/SpikeInterface) object & attaches probe geometry, spike sorts using Klusta, and allows curation of the output in [phy](https://github.com/cortex-lab/phy/)
# ##### Code is also available to handle non-Klusta sorters [here](#non-klusta)
# ##### **N.B.** This requires a Python 3.7 environment with various dependencies installed, including Klusta version 0.95.0, SpikeInterface, and phy. There is code to install most of these from within the notebook: [Install Dependencies](#install-dependencies)
# ##### It is currently set up to handle a single input file at a time, set manually

# %% [markdown]
# ### To Do List:
# ##### - Incorporate handling multiple files in a loop from a spreadsheet of all recordings
# ##### - Handle concatenating multiple recordings in a single session to sort together, and allow subsequent separation
#
# - Tetrodes: ensure correct marking of which cells come from which tetrodes to allow comparison with Tint
# - Tetrodes: work out the best way to split tetrodes for sorting and curation
#     - Possible solution: make into a single probe with 8 shanks
#
# #### - Set up some sort of spike sorter comparison
# ---

# %% [markdown]
# #### Import all the necessary spikeinterface packages (some currently unused)

# %%
import spikeinterface.extractors as se
from pathlib import Path
from utils import *
import os
import phy.apps.kwik

# %matplotlib widget

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) #gets rid of some annoying warnings

# %% [markdown]
# #### Load data & get basic information about recording

# %%
## Load Tetrode Data
base_folder = Path("/home/isabella/Documents/isabella/jake/recording_data")
recording_name = '201028b_famBox'
recording = se.read_axona(f"{base_folder}/{recording_name}.set")
electrode_type = 'tetrode' # 'probe' or 'tetrode'
tetrode_count = 8

## Load Probe Data
# base_folder = Path('/home/isabella/Documents/isabella/klusta_testdata')
# recording_name = '220624a_famBox'
# recording = se.read_axona(f"{base_folder}/{recording_name}.set")
# electrode_type = 'probe' # 'probe' or 'tetrode'

## Get some basic information about the recording
fs = recording.get_sampling_frequency()
num_chan = recording.get_num_channels()
num_segments = recording.get_num_segments()
duration = recording.get_total_duration()

## Invert trace if necessary
# recording = spre.scale(recording, gain=-1)

print(f'Number of channels: {num_chan}')
print(f'Total Duration: {duration} seconds')
print(f"Number of segments: {num_segments}")
print(f'Sampling frequency: {fs} Hz')
# Out:
# Number of channels: 64
# Total Duration: 600.0625 seconds
# Number of segments: 1
# Sampling frequency: 48000.0 Hz

# %% [markdown]
# #### Load probe and assign to recording, cut down to 32 channels
# - N.B. 8 tetrodes are treated as a single shank probe, with tetrodes spaced 300um apart

# %%
recording_preprocessed = preprocess(recording, recording_name, base_folder, electrode_type, num_channels = 64)
# Out:
# write_binary_recording with n_jobs = 1 and chunk_size = None
# Recording preprocessed and saved
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Sort using klusta
# - Load sorted file if it already exists, otherwise apply a sorting algorithm to recording, then aggregate into a single recording object and save
# - N.B. tetrodes are sorted together as if a single shank

# %%
## Load sorted file if it already exists, otherwise apply a sorting algorithm to recording,
## then aggregate into a single recording object and save
## N.B. tetrodes are sorted together as if a single shank

recording_sorted = sort(recording_preprocessed, recording_name, base_folder, sorting_suffix = 'sorting_2_5')
# Out:
# write_binary_recording:   0%|          | 0/601 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/201028b_famBox_sorting_2_5/run_klusta.sh
# 15:42:50 [I] creator:446          Using kwik file `/data/isabella/jake/recording_data/201028b_famBox_sorting_2_5/recording.kwik`.
#
# 15:42:50 [I] launch:206           Starting spike detection.
#
# 15:42:50 [I] launch:53            SpikeDetekt parameters:
#
# 15:42:50 [I] launch:55            chunk_overlap_seconds = 0.015
#
# 15:42:50 [I] launch:55            chunk_size_seconds = 3
#
# 15:42:50 [I] launch:55            connected_component_join_size = 1
#
# 15:42:50 [I] launch:55            detect_spikes = negative
#
# 15:42:50 [I] launch:55            dtype = int16
#
# 15:42:50 [I] launch:55            excerpt_size_seconds = 1
#
# 15:42:50 [I] launch:55            experiment_name = recording.kwik
#
# 15:42:50 [I] launch:55            extract_s_after = 32
#
# 15:42:50 [I] launch:55            extract_s_before = 16
#
# 15:42:50 [I] launch:55            filter_butter_order = 3
#
# 15:42:50 [I] launch:55            filter_high_factor = 0.475
#
# 15:42:50 [I] launch:55            filter_low = 500.0
#
# 15:42:50 [I] launch:55            n_channels = 32
#
# 15:42:50 [I] launch:55            n_excerpts = 50
#
# 15:42:50 [I] launch:55            n_features_per_channel = 3
#
# 15:42:50 [I] launch:55            pca_n_waveforms_max = 10000
#
# 15:42:50 [I] launch:55            prb_file = /home/isabella/Documents/isabella/jake/recording_data/201028b_famBox_sorting_2_5/probe.prb
#
# 15:42:50 [I] launch:55            raw_data_files = /home/isabella/Documents/isabella/jake/recording_data/201028b_famBox_sorting_2_5/recording.dat
#
# 15:42:50 [I] launch:55            sample_rate = 48000.0
#
# 15:42:50 [I] launch:55            threshold_strong_std_factor = 5
#
# 15:42:50 [I] launch:55            threshold_weak_std_factor = 2
#
# 15:42:50 [I] launch:55            use_single_threshold = 1
#
# 15:42:50 [I] launch:55            voltage_gain = 1.0
#
# 15:42:50 [I] launch:55            weight_power = 2
#
# 15:42:50 [I] spikedetekt:212      Found 32 live channels in group 0.
#
# 15:42:50 [I] spikedetekt:285      Finding the thresholds...
#
#
#
# Detecting spikes        :   0%|          | 0/202 [00:00<?, ?it/s]
#
# Detecting spikes        :   0%|          | 1/202 [00:01<06:12,  1.85s/it]
#
# Detecting spikes        :   1%|          | 2/202 [00:03<05:23,  1.62s/it]
#
# Detecting spikes        :   1%|▏         | 3/202 [00:04<05:15,  1.58s/it]
#
# Detecting spikes        :   2%|▏         | 4/202 [00:06<05:22,  1.63s/it]
#
# Detecting spikes        :   2%|▏         | 5/202 [00:08<05:27,  1.66s/it]
#
# Detecting spikes        :   3%|▎         | 6/202 [00:10<06:15,  1.92s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1666/1755942996.py in <module>
#       3 ## N.B. tetrodes are sorted together as if a single shank
#       4
# ----> 5 recording_sorted = sort(recording_preprocessed, recording_name, base_folder, sorting_suffix = 'sorting_2_5')
#
# /data/isabella/klusta_testdata/spikeinterface/utils.py in sort(recording, recording_name, base_folder, sorting_suffix)
#      95     else:
#      96         sorting = ss.run_sorter('klusta', recording, output_folder=f"{sorting_path}",
# ---> 97                                 verbose = True, docker_image = False, **custom_sorter_params())
#      98         sorting = sorting.remove_empty_units()
#      99
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/spikeinterface/sorters/runsorter.py in run_sorter(sorter_name, recording, output_folder, remove_existing_folder, delete_output_folder, verbose, raise_error, docker_image, singularity_image, with_output, **sorter_params)
#     140         )
#     141
# --> 142     return run_sorter_local(**common_kwargs)
#     143
#     144
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/spikeinterface/sorters/runsorter.py in run_sorter_local(sorter_name, recording, output_folder, remove_existing_folder, delete_output_folder, verbose, raise_error, with_output, **sorter_params)
#     160         recording, output_folder, sorter_params, verbose)
#     161     SorterClass.setup_recording(recording, output_folder, verbose=verbose)
# --> 162     SorterClass.run_from_folder(output_folder, raise_error, verbose)
#     163     if with_output:
#     164         sorting = SorterClass.get_result_from_folder(output_folder)
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/spikeinterface/sorters/basesorter.py in run_from_folder(cls, output_folder, raise_error, verbose)
#     223
#     224         try:
# --> 225             SorterClass._run_from_folder(output_folder, sorter_params, verbose)
#     226             t1 = time.perf_counter()
#     227             run_time = float(t1 - t0)
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/spikeinterface/sorters/klusta/klusta.py in _run_from_folder(cls, output_folder, params, verbose)
#     146         shell_script = ShellScript(shell_cmd, script_path=output_folder / f'run_{cls.sorter_name}',
#     147                                    log_path=output_folder / f'{cls.sorter_name}.log', verbose=verbose)
# --> 148         shell_script.start()
#     149
#     150         retcode = shell_script.wait()
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/spikeinterface/sorters/utils/shellscript.py in start(self)
#      81                                          universal_newlines=True)
#      82         with open(script_log_path, 'w+') as script_log_file:
# ---> 83             for line in self._process.stdout:
#      84                 script_log_file.write(line)
#      85                 if self._verbose:  # Print onto console depending on the verbose property passed on from the sorter class
#
# KeyboardInterrupt:

# %%
#Run phy on klusta output
os.environ["QTWEBENGINE_CHROMIUM_FLAGS"] = "--single-process"

## If tetrodes sorted separately, change channel_group to choose tetrode to display in phy
phy.apps.kwik.kwik_gui(sorting_path/'recording.kwik', channel_group=None, clustering=None)

# %% [markdown]
# ---
# ## Currently unused code:
# <a id="non-klusta"></a>
# #### For use with non-phy-integrated sorters:

# %%
## Highpass filter and reference data, then extract waveforms for use in spikeinterface GUI
## If using klusta, the same thing can be viewed using phy with the blocks above
## This is more useful when using other sorters

# recording = si.load_extractor(base_folder / "preprocessed")
# recording_to_process = recording
# recording_f = spre.bandpass_filter(recording_to_process, freq_min=300, freq_max=6000)
# recording_cmr = spre.common_reference(recording_f, reference='global', operator='median')
# fs = recording_cmr.get_sampling_frequency()

# sorting = si.load_extractor(sorting_path / 'sort')

# we = si.extract_waveforms(recording_cmr, sorting, folder=base_folder / "waveforms", 
#                           load_if_exists=False, overwrite=True)
# print(we)

# # Export to phy
# sexp.export_to_phy(we, output_folder=base_folder / 'phy', 
#           compute_amplitudes=True, compute_pc_features=True, copy_binary=True, peak_sign = 'neg', verbose = True)

# # Run phy on spikeinterface waveform output
# %cd {base_folder}
# !phy template-gui phy/params.py



## Create waveform GUI as webpage, requires some setup steps on a new machine
## Found here: https://spikeinterface.readthedocs.io/en/latest/modules/widgets.html#sorting-view

# import kachery_cloud as kcl
# kcl.init()
# waveforms0 = we.get_waveforms(unit_id=0)
# print(f"Waveforms shape: {waveforms0.shape}")
# template0 = we.get_template(unit_id=0)
# print(f"Template shape: {template0.shape}")
# all_templates = we.get_all_templates()
# print(f"All templates shape: {all_templates.shape}")
# correlograms = spost.compute_correlograms(we)
# amps = spost.compute_spike_amplitudes(we)
# locs = spost.compute_unit_locations(we)
# sim = spost.compute_template_similarity(we)
# sw.plot_sorting_summary(we, backend='sortingview')

# %%
## Recording utils
# recording.annotate(is_filtered=False)
# channel_ids = recording.get_channel_ids()
# print(f'Channel ids: {channel_ids}')

# %% [markdown]
# #### Code to generate tetrodes for sorting on individual tetrodes

# %%
## Generate tetrodes (if tetrode recording) and assign to recording channels
# if electrode_type == 'tetrode':
#     ## Function to produce tetrode objects and assign them to a ProbeGroup
#     from utils import generate_tetrodes 
    
#     if (base_folder / "preprocessed").is_dir():
#         recording = si.load_extractor(base_folder / "preprocessed")
#         print('Tetrode recording loaded from previous preprocessing')
#         generate_tetrodes(tetrode_count)

        
#     else:
#         recording = recording.set_probegroup(generate_tetrodes(tetrode_count), group_mode='by_probe')
#         recording_saved = recording.save(folder=base_folder / "preprocessed")
#         print('Tetrode recording saved to "preprocessed" folder')
    
#     recordings = recording.split_by(property='group', outputs='dict')
#     print(f'Recording split into {tetrode_count} tetrodes')
# Out:
# write_binary_recording with n_jobs = 1 and chunk_size = None
# Tetrode recording saved to "preprocessed" folder
# Recording split into 8 tetrodes
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Code to sort using Klusta by individual tetrodes

# %%
# import spikeinterface.sorters as ss
# import spikeinterface as si
# sortings = {}
# for group, sub_recording in recordings.items():
#     sorting = ss.run_sorter('klusta', sub_recording, output_folder=f"{base_folder}/sorting", verbose = False, docker_image = False)
#     sortings[group] = sorting
#     print(f"Tetrode {group+1} of {tetrode_count} Done!")

# for i in list(sortings):
#     if i == 0:
#         sortings_agg = sortings[0]
#     else:
#         sortings_agg = si.aggregate_units([sortings_agg, sortings[i]])
# sorting = sortings_agg

## Plot raster plots per tetrode
# for i in range(1,len(sortings)):
#     raster = sw.plot_rasters(sortings)
#     plt.savefig(f'C:/Users/jakes/Documents/recording_data/r1299/2023-01-24/plots/raster_tetrode{i}.png')
# Out:
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/sorting/run_klusta.sh
# Tetrode 1 of 8 Done!
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/sorting/run_klusta.sh
# Tetrode 2 of 8 Done!
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/sorting/run_klusta.sh
# Tetrode 3 of 8 Done!
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/sorting/run_klusta.sh
# Tetrode 4 of 8 Done!
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/sorting/run_klusta.sh
# Tetrode 5 of 8 Done!
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/sorting/run_klusta.sh
# Tetrode 6 of 8 Done!
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/sorting/run_klusta.sh
# Tetrode 7 of 8 Done!
# RUNNING SHELL SCRIPT: /home/isabella/Documents/isabella/jake/recording_data/sorting/run_klusta.sh
# Tetrode 8 of 8 Done!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1666/294427587.py in <module>
#      10         sortings_agg = sortings[0]
#      11     else:
# ---> 12         sortings_agg = si.aggregate_units([sortings_agg, sortings[i]])
#      13 sorting = sortings_agg
#      14
#
# NameError: name 'si' is not defined

# %% [markdown]
# <a id="install-dependencies"></a>
# ## Install Dependencies

# %%
## Install spike interface if not already installed
# !pip install spikeinterface

## Install klusta and its dependencies if not already installed
# !pip install Cython h5py tqdm
# !pip install click klusta klustakwik2

## Install phy and dependencies if not already installed
# !conda activate si_env
# !pip install PyQt5==5.12.3
# !pip install pyqtwebengine==5.12.1
# !pip install phy --pre --upgrade

## Check which sorters are installed locally
# ss.installed_sorters()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1666/3818302517.py in <module>
# ----> 1 phy.apps.kwik.kwik_gui('/home/isabella/Documents/isabella/jake/recording_data/sorting/recording.kwik', channel_group=1, clustering=None)
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/phy/apps/kwik/gui.py in kwik_gui(path, channel_group, clustering, **kwargs)
#     243     create_app()
#     244     controller = KwikController(
# --> 245         path, channel_group=channel_group, clustering=clustering, **kwargs)
#     246     gui = controller.create_gui()
#     247     gui.show()
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/phy/apps/kwik/gui.py in __init__(self, kwik_path, **kwargs)
#     103         self.channel_group = kwargs.get('channel_group', None)
#     104         self.clustering = kwargs.get('clustering', None)
# --> 105         super(KwikController, self).__init__(kwik_path=kwik_path, dir_path=dir_path, **kwargs)
#     106
#     107     # Internal methods
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/phy/apps/base.py in __init__(self, dir_path, config_dir, model, clear_cache, clear_state, enable_threading, **kwargs)
#     879
#     880         # Create or reuse a Model instance (any object)
# --> 881         self.model = self._create_model(dir_path=dir_path, **kwargs) if model is None else model
#     882
#     883         # Set up the cache.
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/phy/apps/kwik/gui.py in _create_model(self, **kwargs)
#     122         _backup(kwik_path)
#     123         kwargs = {k: v for k, v in kwargs.items() if k in ('clustering', 'channel_group')}
# --> 124         model = KwikModelGUI(str(kwik_path), **kwargs)
#     125         # HACK: handle badly formed channel positions
#     126         if model.channel_positions.ndim == 1:  # pragma: no cover
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/klusta/kwik/model.py in __init__(self, kwik_path, channel_group, clustering, waveform_filter)
#     591         self.open(kwik_path,
#     592                   channel_group=channel_group,
# --> 593                   clustering=clustering)
#     594
#     595     @property
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/klusta/kwik/model.py in open(self, kwik_path, channel_group, clustering)
#    1054         # This needs the recording offsets.
#    1055         # This loads channels, channel_order, spikes, probe.
# -> 1056         self._channel_group_changed(self._channel_group)
#    1057
#    1058         # This loads spike clusters and cluster groups.
#
# ~/anaconda3/envs/env_37/lib/python3.7/site-packages/klusta/kwik/model.py in _channel_group_changed(self, value)
#    1116         """Called when the channel group changes."""
#    1117         if value not in self.channel_groups:
# -> 1118             raise ValueError("The channel group {0} is invalid.".format(value))
#    1119         self._channel_group = value
#    1120
#
# ValueError: The channel group 1 is invalid.
