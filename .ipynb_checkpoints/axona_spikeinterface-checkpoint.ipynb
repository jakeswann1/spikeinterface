# %% [markdown]
# # SpikeInterface Processing Pipeline for Tetrodes & Neuronexus Probe
# ### Jake Swann
#
# ##### This is a notebook which takes raw Axona recordings (1 .set and 1 .bin file per recording), loads them as a [SpikeInterface](https://github.com/SpikeInterface) object & attaches probe geometry, spike sorts using Klusta, and allows curation of the output in [phy](https://github.com/cortex-lab/phy/)
# ##### Code is also available to handle non-Klusta sorters [here](#non-klusta)
# ##### **NB** This requires a Python 3.7 environment with various dependencies installed, including Klusta version 0.95.0, SpikeInterface, and phy. There is code to install most of these from within the notebook: [Install Dependencies](#install-dependencies)
# ##### It is currently set up to handle a single input file at a time, set manually

# %% [markdown]
# ### To Do List:
# ##### - Incorporate handling multiple files in a loop from a spreadsheet of all recordings
# ##### - Handle concatenating multiple recordings in a single session to sort together, and allow subsequent separation
#
# - Tetrodes: ensure correct marking of which cells come from which tetrodes to allow comparison with Tint
# - Tetrodes: work out the best way to split tetrodes for sorting and curation
#     - Possible solution: make into a single probe with 8 shanks
# ---

# %% [markdown]
# #### Import all the necessary spikeinterface packages (some currently unused)

# %%
import spikeinterface as si
import spikeinterface.extractors as se
import spikeinterface.preprocessing as spre
import spikeinterface.sorters as ss
import spikeinterface.postprocessing as spost
import spikeinterface.qualitymetrics as sqm
import spikeinterface.comparison as sc
import spikeinterface.exporters as sexp
import spikeinterface.widgets as sw
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
# %matplotlib widget

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) #gets rid of some annoying warnings

# %% [markdown]
# #### Load data & get basic information about recording

# %%
## Load Tetrode Data
base_folder = Path("/data/isabella/jake/recording_data/r1299/2023-01-24/")
recording = se.read_axona(f"{base_folder}/2023-01-24_r1299_t-maze_2_raw.set")
electrode_type = 'tetrode' # 'probe' or 'tetrode'
tetrode_count = 8

## Load Probe Data
# base_folder = Path('/home/isabella/Documents/isabella/klusta_testdata')
# recording = se.read_axona(f"{base_folder}/220624a_famBox.set")
# electrode_type = 'probe' # 'probe' or 'tetrode'


## Get some basic information about the recording
fs = recording.get_sampling_frequency()
num_chan = recording.get_num_channels()
num_segments = recording.get_num_segments()
duration = recording.get_total_duration()


## Invert trace if necessary
# recording = spre.scale(recording, gain=-1)

print(f'Number of channels: {num_chan}')
print(f'Total Duration: {duration} seconds')
print(f"Number of segments: {num_segments}")
print(f'Sampling frequency: {fs} Hz')
# Out:
# Number of channels: 32
# Total Duration: 600.00625 seconds
# Number of segments: 1
# Sampling frequency: 48000.0 Hz

# %% [markdown]
# #### Generate tetrodes or load probe and assign to recordong

# %%
from probeinterface import read_prb
from probeinterface.plotting import plot_probe, plot_probe_group

if electrode_type == 'tetrode':
    probe = read_prb('/home/isabella/Documents/isabella/klusta_testdata/spikeinterface/8_tetrodes.prb') #Load probe
elif electrode_type == 'probe':
    probe = read_prb('/home/isabella/Documents/isabella/klusta_testdata/spikeinterface/4x8_buzsaki_oneshank.prb') #Load probe
else:
    raise ValueError('Electrode type is set wrong, please set to either "probe" or "tetrode"')
    
plot_probe_group(probe, with_channel_index = True)
#plt.savefig(f'{base_folder}/probe_layout.png')

if (base_folder / "preprocessed").is_dir():
    recording = si.load_extractor(base_folder / "preprocessed")
    print(f'32-channel {electrode_type} recording loaded from previous preprocessing')
    print(recording)
else:
    channel_ids = recording.get_channel_ids()
    recording = recording.channel_slice(channel_ids=channel_ids[:32]) #Cut out empty channels 33-64

    ## Currently necessary as the probe is being treated as a single shank
    ## This turns the probe object from ProbeGroup to Probe
    import probeinterface.probe
    singleProbe = probeinterface.Probe.from_dict(probe.to_dict()['probes'][0])
    recording = recording.set_probe(singleProbe)

    recording_saved = recording.save(folder=base_folder / "preprocessed")
    print('Recording preprocessed and saved')
# Out:
# write_binary_recording with n_jobs = 1 and chunk_size = None
# Recording preprocessed and saved
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Sort using klusta

# %%
## Load sorted file if it already exists, otherwise apply a sorting algorithm to recording,
## then aggregate into a single recording object and save
## N.B. tetrodes are sorted together, but as separate channel groups

sorting_path = Path(f'{base_folder}/sorting') # Can be changed if you want to hold on to multiple sorts

if (sorting_path).is_dir():
    sorting = si.load_extractor(sorting_path / 'sort')
    print(f"Sorting loaded from file {sorting_path}")

else:
    sorting = ss.run_sorter('klusta', recording, output_folder=f"{sorting_path}", verbose = False, docker_image = False)
    sorting = sorting.remove_empty_units()
    
    print('\nSorting Complete\n', sorting, '\nKlusta found', len(sorting.get_unit_ids()), 'non-empty units')
    sorting_saved = sorting.save(folder=sorting_path / 'sort')
    print(f'Sorting saved to {sorting_path}/sort')

print(sorting)
raster = sw.plot_rasters(sorting)
# Out:
# write_binary_recording:   0%|          | 0/601 [00:00<?, ?it/s]
# RUNNING SHELL SCRIPT: /data/isabella/jake/recording_data/r1299/2023-01-24/sorting/run_klusta.sh
# 12:42:45 [I] creator:446          Using kwik file `/data/isabella/jake/recording_data/r1299/2023-01-24/sorting/recording.kwik`.
#
# 12:42:45 [I] launch:206           Starting spike detection.
#
# 12:42:45 [I] launch:53            SpikeDetekt parameters:
#
# 12:42:45 [I] launch:55            chunk_overlap_seconds = 0.015
#
# 12:42:45 [I] launch:55            chunk_size_seconds = 3
#
# 12:42:45 [I] launch:55            connected_component_join_size = 1
#
# 12:42:45 [I] launch:55            detect_spikes = negative
#
# 12:42:45 [I] launch:55            dtype = int16
#
# 12:42:45 [I] launch:55            excerpt_size_seconds = 1
#
# 12:42:45 [I] launch:55            experiment_name = recording.kwik
#
# 12:42:45 [I] launch:55            extract_s_after = 32
#
# 12:42:45 [I] launch:55            extract_s_before = 16
#
# 12:42:45 [I] launch:55            filter_butter_order = 3
#
# 12:42:45 [I] launch:55            filter_high_factor = 0.475
#
# 12:42:45 [I] launch:55            filter_low = 500.0
#
# 12:42:45 [I] launch:55            n_channels = 32
#
# 12:42:45 [I] launch:55            n_excerpts = 50
#
# 12:42:45 [I] launch:55            n_features_per_channel = 3
#
# 12:42:45 [I] launch:55            pca_n_waveforms_max = 10000
#
# 12:42:45 [I] launch:55            prb_file = /data/isabella/jake/recording_data/r1299/2023-01-24/sorting/probe.prb
#
# 12:42:45 [I] launch:55            raw_data_files = /data/isabella/jake/recording_data/r1299/2023-01-24/sorting/recording.dat
#
# 12:42:45 [I] launch:55            sample_rate = 48000.0
#
# 12:42:45 [I] launch:55            threshold_strong_std_factor = 5
#
# 12:42:45 [I] launch:55            threshold_weak_std_factor = 2
#
# 12:42:45 [I] launch:55            use_single_threshold = 1
#
# 12:42:45 [I] launch:55            voltage_gain = 1.0
#
# 12:42:45 [I] launch:55            weight_power = 2
#
# 12:42:45 [I] spikedetekt:212      Found 32 live channels in group 0.
#
# 12:42:45 [I] spikedetekt:285      Finding the thresholds...
#
#
#
# Detecting spikes        :   0%|          | 0/202 [00:00<?, ?it/s]
#
# Detecting spikes        :   0%|          | 1/202 [00:01<05:46,  1.72s/it]
#
# Detecting spikes        :   1%|          | 2/202 [00:03<05:51,  1.76s/it]
#
# Detecting spikes        :   1%|▏         | 3/202 [00:05<05:51,  1.77s/it]
#
# Detecting spikes        :   2%|▏         | 4/202 [00:07<05:54,  1.79s/it]
#
# Detecting spikes        :   2%|▏         | 5/202 [00:09<06:22,  1.94s/it]
#
# Detecting spikes        :   3%|▎         | 6/202 [00:11<06:17,  1.92s/it]
#
# Detecting spikes        :   3%|▎         | 7/202 [00:13<06:17,  1.94s/it]
#
# Detecting spikes        :   4%|▍         | 8/202 [00:15<06:09,  1.90s/it]
#
# Detecting spikes        :   4%|▍         | 9/202 [00:16<05:58,  1.86s/it]
#
# Detecting spikes        :   5%|▍         | 10/202 [00:18<05:49,  1.82s/it]
#
# Detecting spikes        :   5%|▌         | 11/202 [00:20<05:49,  1.83s/it]
#
# Detecting spikes        :   6%|▌         | 12/202 [00:22<05:56,  1.88s/it]
#
# Detecting spikes        :   6%|▋         | 13/202 [00:24<05:55,  1.88s/it]
#
# Detecting spikes        :   7%|▋         | 14/202 [00:26<05:51,  1.87s/it]
#
# Detecting spikes        :   7%|▋         | 15/202 [00:27<05:39,  1.82s/it]
#
# Detecting spikes        :   8%|▊         | 16/202 [00:29<05:37,  1.82s/it]
#
# Detecting spikes        :   8%|▊         | 17/202 [00:31<05:37,  1.83s/it]
#
# Detecting spikes        :   9%|▉         | 18/202 [00:33<05:42,  1.86s/it]
#
# Detecting spikes        :   9%|▉         | 19/202 [00:35<05:37,  1.85s/it]
#
# Detecting spikes        :  10%|▉         | 20/202 [00:37<05:35,  1.84s/it]
#
# Detecting spikes        :  10%|█         | 21/202 [00:38<05:22,  1.78s/it]
#
# Detecting spikes        :  11%|█         | 22/202 [00:40<05:19,  1.78s/it]
#
# Detecting spikes        :  11%|█▏        | 23/202 [00:42<05:15,  1.76s/it]
#
# Detecting spikes        :  12%|█▏        | 24/202 [00:43<05:12,  1.76s/it]
#
# Detecting spikes        :  12%|█▏        | 25/202 [00:45<05:14,  1.77s/it]
#
# Detecting spikes        :  13%|█▎        | 26/202 [00:47<05:09,  1.76s/it]
#
# Detecting spikes        :  13%|█▎        | 27/202 [00:49<05:06,  1.75s/it]
#
# Detecting spikes        :  14%|█▍        | 28/202 [00:50<05:01,  1.73s/it]
#
# Detecting spikes        :  14%|█▍        | 29/202 [00:52<05:16,  1.83s/it]
#
# Detecting spikes        :  15%|█▍        | 30/202 [00:55<05:29,  1.91s/it]
#
# Detecting spikes        :  15%|█▌        | 31/202 [00:56<05:21,  1.88s/it]
#
# Detecting spikes        :  16%|█▌        | 32/202 [00:58<05:28,  1.93s/it]
#
# Detecting spikes        :  16%|█▋        | 33/202 [01:00<05:25,  1.92s/it]
#
# Detecting spikes        :  17%|█▋        | 34/202 [01:02<05:14,  1.87s/it]
#
# Detecting spikes        :  17%|█▋        | 35/202 [01:04<05:09,  1.85s/it]
#
# Detecting spikes        :  18%|█▊        | 36/202 [01:06<04:58,  1.80s/it]
#
# Detecting spikes        :  18%|█▊        | 37/202 [01:07<04:55,  1.79s/it]
#
# Detecting spikes        :  19%|█▉        | 38/202 [01:09<04:50,  1.77s/it]
#
# Detecting spikes        :  19%|█▉        | 39/202 [01:11<04:46,  1.76s/it]
#
# Detecting spikes        :  20%|█▉        | 40/202 [01:12<04:43,  1.75s/it]
#
# Detecting spikes        :  20%|██        | 41/202 [01:14<04:44,  1.77s/it]
#
# Detecting spikes        :  21%|██        | 42/202 [01:16<04:39,  1.75s/it]
#
# Detecting spikes        :  21%|██▏       | 43/202 [01:18<04:34,  1.73s/it]
#
# Detecting spikes        :  22%|██▏       | 44/202 [01:20<04:50,  1.84s/it]
#
# Detecting spikes        :  22%|██▏       | 45/202 [01:22<04:46,  1.82s/it]
#
# Detecting spikes        :  23%|██▎       | 46/202 [01:24<04:51,  1.87s/it]
#
# Detecting spikes        :  23%|██▎       | 47/202 [01:25<04:46,  1.85s/it]
#
# Detecting spikes        :  24%|██▍       | 48/202 [01:27<04:40,  1.82s/it]
#
# Detecting spikes        :  24%|██▍       | 49/202 [01:29<04:35,  1.80s/it]
#
# Detecting spikes        :  25%|██▍       | 50/202 [01:31<04:35,  1.81s/it]
#
# Detecting spikes        :  25%|██▌       | 51/202 [01:33<04:44,  1.88s/it]
#
# Detecting spikes        :  26%|██▌       | 52/202 [01:35<04:46,  1.91s/it]
#
# Detecting spikes        :  26%|██▌       | 53/202 [01:37<04:43,  1.90s/it]
#
# Detecting spikes        :  27%|██▋       | 54/202 [01:39<04:44,  1.92s/it]
#
# Detecting spikes        :  27%|██▋       | 55/202 [01:40<04:39,  1.90s/it]
#
# Detecting spikes        :  28%|██▊       | 56/202 [01:42<04:38,  1.91s/it]
#
# Detecting spikes        :  28%|██▊       | 57/202 [01:44<04:31,  1.87s/it]
#
# Detecting spikes        :  29%|██▊       | 58/202 [01:46<04:27,  1.86s/it]
#
# Detecting spikes        :  29%|██▉       | 59/202 [01:48<04:27,  1.87s/it]
#
# Detecting spikes        :  30%|██▉       | 60/202 [01:50<04:28,  1.89s/it]
#
# Detecting spikes        :  30%|███       | 61/202 [01:52<04:23,  1.87s/it]
#
# Detecting spikes        :  31%|███       | 62/202 [01:53<04:19,  1.85s/it]
#
# Detecting spikes        :  31%|███       | 63/202 [01:55<04:13,  1.82s/it]
#
# Detecting spikes        :  49%|████▉     | 99/202 [03:01<03:05,  1.80s/it]
#
# Detecting spikes        :  50%|████▉     | 100/202 [03:03<03:06,  1.83s/it]
#
# Detecting spikes        :  50%|█████     | 101/202 [03:05<03:09,  1.88s/it]
#
# Detecting spikes        :  50%|█████     | 102/202 [03:07<03:04,  1.84s/it]
#
# Detecting spikes        :  51%|█████     | 103/202 [03:08<03:00,  1.82s/it]
#
# Detecting spikes        :  51%|█████▏    | 104/202 [03:10<03:00,  1.84s/it]
#
# Detecting spikes        :  52%|█████▏    | 105/202 [03:12<02:57,  1.83s/it]
#
# Detecting spikes        :  52%|█████▏    | 106/202 [03:14<02:53,  1.81s/it]
#
# Detecting spikes        :  53%|█████▎    | 107/202 [03:16<02:50,  1.79s/it]
#
# Detecting spikes        :  53%|█████▎    | 108/202 [03:17<02:47,  1.78s/it]
#
# Detecting spikes        :  54%|█████▍    | 109/202 [03:19<02:50,  1.84s/it]
#
# Detecting spikes        :  54%|█████▍    | 110/202 [03:21<02:55,  1.91s/it]
#
# Detecting spikes        :  55%|█████▍    | 111/202 [03:23<02:54,  1.91s/it]
#
# Detecting spikes        :  55%|█████▌    | 112/202 [03:25<02:53,  1.93s/it]
#
# Detecting spikes        :  56%|█████▌    | 113/202 [03:27<02:46,  1.87s/it]
#
# Detecting spikes        :  56%|█████▋    | 114/202 [03:29<02:42,  1.85s/it]
#
# Detecting spikes        :  57%|█████▋    | 115/202 [03:31<02:36,  1.80s/it]
#
# Detecting spikes        :  57%|█████▋    | 116/202 [03:32<02:33,  1.78s/it]
#
# Detecting spikes        :  58%|█████▊    | 117/202 [03:34<02:27,  1.74s/it]
#
# Detecting spikes        :  58%|█████▊    | 118/202 [03:36<02:27,  1.76s/it]
#
# Detecting spikes        :  59%|█████▉    | 119/202 [03:38<02:28,  1.79s/it]
#
# Detecting spikes        :  59%|█████▉    | 120/202 [03:39<02:25,  1.77s/it]
#
# Detecting spikes        :  60%|█████▉    | 121/202 [03:41<02:30,  1.86s/it]
#
# Detecting spikes        :  60%|██████    | 122/202 [03:43<02:27,  1.85s/it]
#
# Detecting spikes        :  61%|██████    | 123/202 [03:45<02:26,  1.85s/it]
#
# Detecting spikes        :  61%|██████▏   | 124/202 [03:47<02:21,  1.81s/it]
#
# Detecting spikes        :  62%|██████▏   | 125/202 [03:49<02:20,  1.83s/it]
#
# Detecting spikes        :  62%|██████▏   | 126/202 [03:50<02:16,  1.80s/it]
#
# Detecting spikes        :  63%|██████▎   | 127/202 [03:52<02:13,  1.78s/it]
#
# Detecting spikes        :  63%|██████▎   | 128/202 [03:54<02:10,  1.77s/it]
#
# Detecting spikes        :  64%|██████▍   | 129/202 [03:56<02:08,  1.76s/it]
#
# Detecting spikes        :  64%|██████▍   | 130/202 [03:57<02:05,  1.74s/it]
#
# Detecting spikes        :  65%|██████▍   | 131/202 [03:59<02:02,  1.72s/it]
#
# Detecting spikes        :  65%|██████▌   | 132/202 [04:01<02:00,  1.72s/it]
#
#
# Detecting spikes        :  83%|████████▎ | 168/202 [05:05<01:00,  1.79s/it]
#
# Detecting spikes        :  84%|████████▎ | 169/202 [05:07<00:57,  1.75s/it]
#
# Detecting spikes        :  84%|████████▍ | 170/202 [05:09<00:56,  1.75s/it]
#
# Detecting spikes        :  85%|████████▍ | 171/202 [05:10<00:54,  1.75s/it]
#
# Detecting spikes        :  85%|████████▌ | 172/202 [05:12<00:52,  1.74s/it]
#
# Detecting spikes        :  86%|████████▌ | 173/202 [05:14<00:51,  1.79s/it]
#
# Detecting spikes        :  86%|████████▌ | 174/202 [05:16<00:51,  1.85s/it]
#
# Detecting spikes        :  87%|████████▋ | 175/202 [05:18<00:50,  1.85s/it]
#
# Detecting spikes        :  87%|████████▋ | 176/202 [05:20<00:49,  1.91s/it]
#
# Detecting spikes        :  88%|████████▊ | 177/202 [05:22<00:47,  1.91s/it]
#
# Detecting spikes        :  88%|████████▊ | 178/202 [05:24<00:45,  1.88s/it]
#
# Detecting spikes        :  89%|████████▊ | 179/202 [05:25<00:42,  1.84s/it]
#
# Detecting spikes        :  89%|████████▉ | 180/202 [05:27<00:39,  1.82s/it]
#
# Detecting spikes        :  90%|████████▉ | 181/202 [05:29<00:37,  1.78s/it]
#
# Detecting spikes        :  90%|█████████ | 182/202 [05:31<00:35,  1.76s/it]
#
# Detecting spikes        :  91%|█████████ | 183/202 [05:32<00:33,  1.75s/it]
#
# Detecting spikes        :  91%|█████████ | 184/202 [05:34<00:31,  1.75s/it]
#
# Detecting spikes        :  92%|█████████▏| 185/202 [05:36<00:30,  1.82s/it]
#
# Detecting spikes        :  92%|█████████▏| 186/202 [05:38<00:29,  1.85s/it]
#
# Detecting spikes        :  93%|█████████▎| 187/202 [05:40<00:27,  1.86s/it]
#
# Detecting spikes        :  93%|█████████▎| 188/202 [05:42<00:25,  1.83s/it]
# Detecting spikes        :  94%|█████████▎| 189/202 [05:43<00:23,  1.84s/it]
#
# Detecting spikes        :  94%|█████████▍| 190/202 [05:45<00:22,  1.85s/it]
#
# Detecting spikes        :  95%|█████████▍| 191/202 [05:47<00:20,  1.84s/it]
#
# Detecting spikes        :  95%|█████████▌| 192/202 [05:49<00:17,  1.78s/it]
#
# Detecting spikes        :  96%|█████████▌| 193/202 [05:51<00:16,  1.85s/it]
#
# Detecting spikes        :  96%|█████████▌| 194/202 [05:53<00:15,  1.88s/it]
#
# Detecting spikes        :  97%|█████████▋| 195/202 [05:55<00:12,  1.85s/it]
#
# Detecting spikes        :  97%|█████████▋| 196/202 [05:56<00:10,  1.82s/it]
#
# Detecting spikes        :  98%|█████████▊| 197/202 [05:58<00:08,  1.80s/it]
#
# Detecting spikes        :  98%|█████████▊| 198/202 [06:00<00:07,  1.81s/it]
#
# Detecting spikes        :  99%|█████████▊| 199/202 [06:02<00:05,  1.80s/it]
#
# Detecting spikes        :  99%|█████████▉| 200/202 [06:04<00:03,  1.91s/it]
#
# Detecting spikes        : 100%|█████████▉| 201/202 [06:06<00:01,  1.89s/it]
#
# Detecting spikes        : 100%|██████████| 202/202 [06:06<00:00,  1.81s/it]
#
#
#
# Extracting waveforms    :   0%|          | 0/202 [00:00<?, ?it/s]
#
# Extracting waveforms    :   1%|▏         | 3/202 [00:00<00:08, 24.52it/s]
#
# Extracting waveforms    :   3%|▎         | 7/202 [00:00<00:07, 24.61it/s]
#
# Extracting waveforms    :   5%|▌         | 11/202 [00:00<00:07, 26.51it/s]
#
# Extracting waveforms    :   8%|▊         | 16/202 [00:00<00:06, 30.83it/s]
#
# Extracting waveforms    :  10%|▉         | 20/202 [00:00<00:06, 28.59it/s]
#
# Extracting waveforms    :  13%|█▎        | 26/202 [00:00<00:04, 35.31it/s]
#
# Extracting waveforms    :  15%|█▍        | 30/202 [00:00<00:05, 31.53it/s]
#
# Extracting waveforms    :  17%|█▋        | 34/202 [00:01<00:05, 30.20it/s]
#
# Extracting waveforms    :  19%|█▉        | 38/202 [00:01<00:05, 31.81it/s]
#
# Extracting waveforms    :  21%|██        | 42/202 [00:01<00:04, 33.39it/s]
#
# Extracting waveforms    :  23%|██▎       | 46/202 [00:01<00:04, 32.75it/s]
#
# Extracting waveforms    :  25%|██▌       | 51/202 [00:01<00:04, 35.35it/s]
#
# Extracting waveforms    :  27%|██▋       | 55/202 [00:01<00:04, 31.79it/s]
#
# Extracting waveforms    :  29%|██▉       | 59/202 [00:01<00:05, 28.49it/s]
#
# Extracting waveforms    :  31%|███       | 62/202 [00:02<00:06, 22.57it/s]
#
# Extracting waveforms    :  33%|███▎      | 66/202 [00:02<00:05, 25.69it/s]
#
# Extracting waveforms    :  36%|███▌      | 73/202 [00:02<00:03, 34.36it/s]
#
# Extracting waveforms    :  40%|███▉      | 80/202 [00:02<00:02, 41.63it/s]
#
# Extracting waveforms    :  43%|████▎     | 86/202 [00:02<00:02, 45.10it/s]
#
# Extracting waveforms    :  45%|████▌     | 91/202 [00:02<00:02, 39.38it/s]
#
# Extracting waveforms    :  48%|████▊     | 96/202 [00:02<00:02, 39.01it/s]
#
# Extracting waveforms    :  50%|█████     | 101/202 [00:03<00:02, 37.35it/s]
#
# Extracting waveforms    :  52%|█████▏    | 106/202 [00:03<00:02, 39.56it/s]
#
# Extracting waveforms    :  55%|█████▍    | 111/202 [00:03<00:02, 34.00it/s]
#
# Extracting waveforms    :  57%|█████▋    | 115/202 [00:03<00:03, 28.32it/s]
#
# Extracting waveforms    :  59%|█████▉    | 119/202 [00:03<00:02, 27.76it/s]
#
# Extracting waveforms    :  60%|██████    | 122/202 [00:03<00:02, 27.77it/s]
#
# Extracting waveforms    :  62%|██████▏   | 126/202 [00:03<00:02, 30.04it/s]
#
# Extracting waveforms    :  64%|██████▍   | 130/202 [00:04<00:02, 27.41it/s]
#
# Extracting waveforms    :  67%|██████▋   | 135/202 [00:04<00:02, 28.94it/s]
#
# Extracting waveforms    :  68%|██████▊   | 138/202 [00:04<00:02, 26.24it/s]
#
# Extracting waveforms    :  70%|███████   | 142/202 [00:04<00:02, 28.03it/s]
#
# Extracting waveforms    :  72%|███████▏  | 146/202 [00:04<00:01, 29.53it/s]
#
# Extracting waveforms    :  75%|███████▌  | 152/202 [00:04<00:01, 35.56it/s]
#
# Extracting waveforms    :  77%|███████▋  | 156/202 [00:04<00:01, 30.88it/s]
#
# Extracting waveforms    :  79%|███████▉  | 160/202 [00:05<00:01, 31.28it/s]
#
# Extracting waveforms    :  81%|████████  | 164/202 [00:05<00:01, 27.01it/s]
#
# Extracting waveforms    :  83%|████████▎ | 167/202 [00:05<00:01, 23.61it/s]
#
# Extracting waveforms    :  85%|████████▍ | 171/202 [00:05<00:01, 23.85it/s]
#
# Extracting waveforms    :  86%|████████▌ | 174/202 [00:05<00:01, 21.66it/s]
#
# Extracting waveforms    :  88%|████████▊ | 177/202 [00:05<00:01, 22.81it/s]
#
# Extracting waveforms    :  90%|████████▉ | 181/202 [00:06<00:00, 24.85it/s]
#
# Extracting waveforms    :  91%|█████████ | 184/202 [00:06<00:00, 22.95it/s]
#
# Extracting waveforms    :  93%|█████████▎| 187/202 [00:06<00:00, 22.88it/s]
#
# Extracting waveforms    :  95%|█████████▍| 191/202 [00:06<00:00, 24.50it/s]
#
# Extracting waveforms    :  96%|█████████▌| 194/202 [00:06<00:00, 23.79it/s]
#
# Extracting waveforms    :  98%|█████████▊| 198/202 [00:06<00:00, 23.30it/s]
#
# Extracting waveforms    : 100%|█████████▉| 201/202 [00:06<00:00, 23.89it/s]
#
# Extracting waveforms    : 100%|██████████| 202/202 [00:06<00:00, 29.30it/s]
#
#
#
# Performing PCA          :   0%|          | 0/1 [00:00<?, ?it/s]
#
# Performing PCA          : 100%|██████████| 1/1 [00:00<00:00,  3.48it/s]
#
# Performing PCA          : 100%|██████████| 1/1 [00:00<00:00,  3.47it/s]
#
#
#
# Computing features      :   0%|          | 0/202 [00:00<?, ?it/s]
#
# Computing features      :   1%|          | 2/202 [00:00<00:17, 11.33it/s]
#
# Computing features      :   2%|▏         | 4/202 [00:00<00:28,  6.99it/s]
#
# Computing features      :   2%|▏         | 5/202 [00:00<00:32,  6.12it/s]
#
# Computing features      :   3%|▎         | 7/202 [00:01<00:31,  6.10it/s]
#
# Computing features      :   4%|▍         | 8/202 [00:01<00:30,  6.31it/s]
#
# Computing features      :   5%|▍         | 10/202 [00:01<00:22,  8.56it/s]
#
# Computing features      :   6%|▌         | 12/202 [00:01<00:28,  6.76it/s]
#
# Computing features      :   7%|▋         | 14/202 [00:01<00:21,  8.59it/s]
#
# Computing features      :   8%|▊         | 16/202 [00:02<00:20,  9.14it/s]
#
# Computing features      :   9%|▉         | 18/202 [00:02<00:22,  8.18it/s]
#
# Computing features      :  10%|▉         | 20/202 [00:02<00:23,  7.64it/s]
#
# Computing features      :  11%|█         | 22/202 [00:02<00:19,  9.07it/s]
#
# Computing features      :  12%|█▏        | 24/202 [00:02<00:16, 10.76it/s]
#
# Computing features      :  13%|█▎        | 27/202 [00:03<00:14, 12.43it/s]
#
# Computing features      :  14%|█▍        | 29/202 [00:03<00:20,  8.33it/s]
#
# Computing features      :  15%|█▌        | 31/202 [00:03<00:18,  9.14it/s]
#
# Computing features      :  89%|████████▉ | 180/202 [00:22<00:02,  7.36it/s]
#
# Computing features      :  90%|████████▉ | 181/202 [00:22<00:03,  6.14it/s]
#
# Computing features      :  91%|█████████ | 183/202 [00:22<00:02,  7.64it/s]
#
# Computing features      :  91%|█████████ | 184/202 [00:23<00:03,  5.33it/s]
#
# Computing features      :  92%|█████████▏| 185/202 [00:23<00:03,  5.34it/s]
#
# Computing features      :  92%|█████████▏| 186/202 [00:23<00:02,  5.89it/s]
#
# Computing features      :  93%|█████████▎| 187/202 [00:23<00:02,  5.18it/s]
#
# Computing features      :  94%|█████████▎| 189/202 [00:23<00:01,  6.93it/s]
#
# Computing features      :  94%|█████████▍| 190/202 [00:24<00:01,  6.62it/s]
#
# Computing features      :  95%|█████████▍| 191/202 [00:24<00:01,  5.77it/s]
#
# Computing features      :  95%|█████████▌| 192/202 [00:24<00:02,  4.18it/s]
#
# Computing features      :  96%|█████████▌| 194/202 [00:24<00:01,  5.77it/s]
#
# Computing features      :  97%|█████████▋| 195/202 [00:25<00:01,  6.26it/s]
#
# Computing features      :  98%|█████████▊| 197/202 [00:25<00:00,  7.81it/s]
#
# Computing features      :  98%|█████████▊| 198/202 [00:25<00:00,  4.89it/s]
#
# Computing features      :  99%|█████████▊| 199/202 [00:25<00:00,  4.86it/s]
#
# Computing features      :  99%|█████████▉| 200/202 [00:26<00:00,  4.76it/s]
#
# Computing features      : 100%|██████████| 202/202 [00:26<00:00,  7.72it/s]
#
# 12:49:32 [I] launch:218           Spike detection done! 55777 spikes found in shank 0
#
# 12:49:33 [I] launch:249           Starting clustering on shank 0/1.
#
# 12:49:33 [I] launch:252           Clustering group 0 (55777 spikes).
#
# 12:49:33 [I] launch:123           Starting KK...
#
# 12:49:35 [I] klustakwik.initial_parameters prior_point = 1
#
# 12:49:35 [I] klustakwik.initial_parameters mua_point = 2
#
# 12:49:35 [I] klustakwik.initial_parameters noise_point = 1
#
# 12:49:35 [I] klustakwik.initial_parameters points_for_cluster_mask = 100
#
# 12:49:35 [I] klustakwik.initial_parameters penalty_k = 0.0
#
# 12:49:35 [I] klustakwik.initial_parameters penalty_k_log_n = 1.0
#
# 12:49:35 [I] klustakwik.initial_parameters max_iterations = 1000
#
# 12:49:35 [I] klustakwik.initial_parameters num_starting_clusters = 50
#
# 12:49:35 [I] klustakwik.initial_parameters use_noise_cluster = True
#
# 12:49:35 [I] klustakwik.initial_parameters use_mua_cluster = True
#
# 12:49:35 [I] klustakwik.initial_parameters num_changed_threshold = 0.05
#
# 12:49:35 [I] klustakwik.initial_parameters full_step_every = 1
#
# 12:49:35 [I] klustakwik.initial_parameters split_first = 20
#
# 12:49:35 [I] klustakwik.initial_parameters split_every = 40
#
# 12:49:35 [I] klustakwik.initial_parameters max_possible_clusters = 1000
#
# 12:49:35 [I] klustakwik.initial_parameters dist_thresh = 9.210340371976182
#
# 12:49:35 [I] klustakwik.initial_parameters max_quick_step_candidates = 100000000
#
# 12:49:35 [I] klustakwik.initial_parameters max_quick_step_candidates_fraction = 0.4
#
# 12:49:35 [I] klustakwik.initial_parameters always_split_bimodal = False
#
# 12:49:35 [I] klustakwik.initial_parameters subset_break_fraction = 0.01
#
# 12:49:35 [I] klustakwik.initial_parameters break_fraction = 0.0
#
# 12:49:35 [I] klustakwik.initial_parameters fast_split = False
#
# 12:49:35 [I] klustakwik.initial_parameters max_split_iterations = None
#
# 12:49:35 [I] klustakwik.initial_parameters consider_cluster_deletion = True
#
# 12:49:35 [I] klustakwik.initial_parameters num_cpus = None
#
# 12:49:35 [I] klustakwik Using mask starts with 50 clusters, data has 30 unique masks
#
# 12:49:35 [W] klustakwik Not enough masks (30) for specified number of starting clusters (50)
#
# 12:49:35 [I] klustakwik Clustering data set of 55777 points, 96 features
#
# 12:49:35 [I] klustakwik Starting iteration 0 with 32 clusters
#
# 12:49:35 [I] klustakwik Deleting cluster 11 (103 points): improves score by 41.624734562821686
#
# 12:49:35 [I] klustakwik Iteration 1F: 32 clusters, 34077 changed, score=-7350369.655642
#
# 12:49:36 [I] klustakwik Deleting cluster 22 (19 points): improves score by 1.1388206174597144
#
# 12:49:36 [I] klustakwik Iteration 2F: 31 clusters, 10299 changed, score=-7487287.605283 (decreased by 136917.949640)
#
# 12:49:37 [I] klustakwik Iteration 3F: 30 clusters, 2289 changed, score=-7497420.641397 (decreased by 10133.036115)
#
# 12:49:38 [I] klustakwik Iteration 4F: 30 clusters, 1115 changed, score=-7500445.063575 (decreased by 3024.422177)
#
# 12:49:39 [I] klustakwik Iteration 5F: 30 clusters, 649 changed, score=-7501506.519819 (decreased by 1061.456244)
# 12:49:39 [I] klustakwik Iteration 6F: 30 clusters, 396 changed, score=-7501880.977432 (decreased by 374.457613)
#
# 12:49:40 [I] klustakwik Iteration 7F: 30 clusters, 254 changed, score=-7502016.491104 (decreased by 135.513672)
#
# 12:49:42 [I] klustakwik Iteration 8F: 30 clusters, 181 changed, score=-7502079.912048 (decreased by 63.420944)
#
# 12:49:43 [I] klustakwik Iteration 9F: 30 clusters, 109 changed, score=-7502113.251103 (decreased by 33.339055)
#
# 12:49:44 [I] klustakwik Iteration 10F: 30 clusters, 88 changed, score=-7502131.267110 (decreased by 18.016007)
#
# 12:49:45 [I] klustakwik Iteration 11F: 30 clusters, 61 changed, score=-7502144.240704 (decreased by 12.973594)
#
# 12:49:46 [I] klustakwik Iteration 12F: 30 clusters, 40 changed, score=-7502151.941432 (decreased by 7.700728)
#
# 12:49:47 [I] klustakwik Iteration 13F: 30 clusters, 32 changed, score=-7502156.731178 (decreased by 4.789747)
#
# 12:49:48 [I] klustakwik Iteration 14F: 30 clusters, 16 changed, score=-7502161.239410 (decreased by 4.508232)
#
# 12:49:49 [I] klustakwik Iteration 15F: 30 clusters, 15 changed, score=-7502167.593217 (decreased by 6.353806)
#
# 12:49:49 [I] klustakwik Iteration 16F: 30 clusters, 13 changed, score=-7502179.533213 (decreased by 11.939996)
#
# 12:49:50 [I] klustakwik Iteration 17F: 30 clusters, 9 changed, score=-7502183.484628 (decreased by 3.951416)
#
# 12:49:51 [I] klustakwik Iteration 18F: 30 clusters, 14 changed, score=-7502192.532180 (decreased by 9.047552)
#
# 12:49:52 [I] klustakwik Iteration 19F: 30 clusters, 16 changed, score=-7502229.143277 (decreased by 36.611097)
#
# 12:49:53 [I] klustakwik Iteration 20F: 30 clusters, 13 changed, score=-7502289.868424 (decreased by 60.725147)
#
# 12:49:53 [I] klustakwik Trying to split clusters
#
# 12:50:12 [I] klustakwik Split into 37 clusters
#
# 12:50:13 [I] klustakwik Iteration 21F: 37 clusters, 55 changed, score=-7503053.085811 (decreased by 763.217387)
#
# 12:50:14 [I] klustakwik Iteration 22F: 37 clusters, 40 changed, score=-7503185.286604 (decreased by 132.200793)
#
# 12:50:15 [I] klustakwik Iteration 23F: 37 clusters, 18 changed, score=-7503308.333673 (decreased by 123.047069)
#
# 12:50:16 [I] klustakwik Iteration 24F: 37 clusters, 10 changed, score=-7503320.116161 (decreased by 11.782488)
#
# 12:50:17 [I] klustakwik Iteration 25F: 37 clusters, 3 changed, score=-7503322.057736 (decreased by 1.941575)
#
# 12:50:18 [I] klustakwik Iteration 26F: 37 clusters, 2 changed, score=-7503321.824808 (decreased by -0.232928)
#
# 12:50:19 [I] klustakwik Iteration 27F: 37 clusters, 4 changed, score=-7503321.895353 (decreased by 0.070545)
#
# 12:50:20 [I] klustakwik Iteration 28F: 37 clusters, 4 changed, score=-7503322.050625 (decreased by 0.155272)
#
# 12:50:21 [I] klustakwik Iteration 29F: 37 clusters, 1 changed, score=-7503322.175951 (decreased by 0.125326)
#
# 12:50:22 [I] klustakwik Iteration 30F: 37 clusters, 1 changed, score=-7503322.217317 (decreased by 0.041366)
#
# 12:50:23 [I] klustakwik Iteration 31F: 37 clusters, 1 changed, score=-7503322.268267 (decreased by 0.050950)
#
# 12:50:25 [I] klustakwik Iteration 32F: 37 clusters, 3 changed, score=-7503322.316847 (decreased by 0.048580)
#
# 12:50:27 [I] klustakwik Iteration 33F: 37 clusters, 2 changed, score=-7503322.455777 (decreased by 0.138930)
#
# 12:50:29 [I] klustakwik Iteration 34F: 37 clusters, 4 changed, score=-7503322.544755 (decreased by 0.088978)
#
# 12:50:30 [I] klustakwik Iteration 35F: 37 clusters, 4 changed, score=-7503322.724093 (decreased by 0.179338)
#
# 12:50:31 [I] klustakwik Iteration 36F: 37 clusters, 4 changed, score=-7503322.909459 (decreased by 0.185366)
#
# 12:50:32 [I] klustakwik Iteration 37F: 37 clusters, 2 changed, score=-7503323.101099 (decreased by 0.191640)
#
# 12:50:33 [I] klustakwik Iteration 38F: 37 clusters, 2 changed, score=-7503323.178901 (decreased by 0.077802)
#
# 12:50:34 [I] klustakwik Iteration 39F: 37 clusters, 0 changed, score=-7503323.233874 (decreased by 0.054973)
#
# 12:50:34 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12
[I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:52:17 [I] klustakwik Trying to split clusters
#
# 12:52:44 [I] klustakwik Split into 47 clusters
#
# 12:52:45 [I] klustakwik Iteration 64F: 47 clusters, 2 changed, score=-7504863.269763 (decreased by 354.906535)
#
# 12:52:46 [I] klustakwik Iteration 65F: 47 clusters, 0 changed, score=-7504855.394087 (decreased by -7.875676)
#
# 12:52:46 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:52:46 [I] klustakwik Trying to split clusters
#
# 12:53:06 [I] klustakwik Split into 49 clusters
#
# 12:53:07 [I] klustakwik Iteration 66F: 49 clusters, 10 changed, score=-7505021.093362 (decreased by 165.699275)
#
# 12:53:08 [I] klustakwik Iteration 67F: 49 clusters, 4 changed, score=-7505000.815977 (decreased by -20.277385)
#
# 12:53:09 [I] klustakwik Iteration 68F: 49 clusters, 1 changed, score=-7505003.801274 (decreased by 2.985297)
# 12:53:10 [I] klustakwik Iteration 69F: 49 clusters, 1 changed, score=-7505004.174150 (decreased by 0.372877)
#
# 12:53:11 [I] klustakwik Iteration 70F: 49 clusters, 0 changed, score=-7505004.476163 (decreased by 0.302013)
#
# 12:53:11 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:53:11 [I] klustakwik Trying to split clusters
#
# 12:53:32 [I] klustakwik Split into 51 clusters
#
# 12:53:33 [I] klustakwik Iteration 71F: 51 clusters, 2 changed, score=-7505128.996368 (decreased by 124.520205)
#
# 12:53:34 [I] klustakwik Iteration 72F: 51 clusters, 1 changed, score=-7505124.939968 (decreased by -4.056400)
#
# 12:53:35 [I] klustakwik Iteration 73F: 51 clusters, 0 changed, score=-7505121.494168 (decreased by -3.445800)
#
# 12:53:35 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:53:35 [I] klustakwik Trying to split clusters
#
# 12:53:55 [I] klustakwik Split into 53 clusters
#
# 12:53:56 [I] klustakwik Iteration 74F: 53 clusters, 8 changed, score=-7505168.917364 (decreased by 47.423196)
#
# 12:53:57 [I] klustakwik Deleting cluster 51 (10 points): improves score by 11.494446905329823
#
# 12:53:57 [I] klustakwik Iteration 75F: 53 clusters, 15 changed, score=-7505123.624622 (decreased by -45.292742)
#
# 12:53:58 [I] klustakwik Iteration 76F: 52 clusters, 3 changed, score=-7505138.706053 (decreased by 15.081431)
#
# 12:53:59 [I] klustakwik Iteration 77F: 52 clusters, 1 changed, score=-7505139.452613 (decreased by 0.746560)
#
# 12:54:00 [I] klustakwik Iteration 78F: 52 clusters, 2 changed, score=-7505139.969995 (decreased by 0.517382)
#
# 12:54:01 [I] klustakwik Iteration 79F: 52 clusters, 1 changed, score=-7505140.646719 (decreased by 0.676724)
#
# 12:54:02 [I] klustakwik Iteration 80F: 52 clusters, 0 changed, score=-7505141.149376 (decreased by 0.502657)
#
# 12:54:02 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:54:02 [I] klustakwik Trying to split clusters
#
# 12:54:23 [I] klustakwik Split into 53 clusters
#
# 12:54:26 [I] klustakwik Iteration 81F: 53 clusters, 0 changed, score=-7505284.717674 (decreased by 143.568297)
#
# 12:54:26 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:54:26 [I] klustakwik Trying to split clusters
#
# 12:54:48 [I] klustakwik Split into 54 clusters
#
# 12:54:49 [I] klustakwik Iteration 82F: 54 clusters, 0 changed, score=-7505375.845358 (decreased by 91.127684)
#
# 12:54:49 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:54:49 [I] klustakwik Trying to split clusters
#
# 12:55:07 [I] klustakwik Split into 55 clusters
#
# 12:55:08 [I] klustakwik Iteration 83F: 55 clusters, 0 changed, score=-7505450.685960 (decreased by 74.840602)
#
# 12:55:08 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:55:08 [I] klustakwik Trying to split clusters
#
# 12:55:33 [I] klustakwik Split into 56 clusters
#
# 12:55:34 [I] klustakwik Iteration 84F: 56 clusters, 2 changed, score=-7505490.757487 (decreased by 40.071527)
#
# 12:55:35 [I] klustakwik Iteration 85F: 56 clusters, 1 changed, score=-7505495.114833 (decreased by 4.357346)
#
# 12:55:36 [I] klustakwik Iteration 86F: 56 clusters, 0 changed, score=-7505494.986485 (decreased by -0.128347)
#
# 12:55:36 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:55:36 [I] klustakwik Trying to split clusters
#
# 12:55:58 [I] klustakwik Split into 58 clusters
#
# 12:55:59 [I] klustakwik Iteration 87F: 58 clusters, 3 changed, score=-7505611.897343 (decreased by 116.910857)
#
# 12:56:00 [I] klustakwik Iteration 88F: 58 clusters, 4 changed, score=-7505631.933575 (decreased by 20.036232)
#
# 12:56:01 [I] klustakwik Iteration 89F: 58 clusters, 0 changed, score=-7505635.615700 (decreased by 3.682125)
#
# 12:56:01 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:56:01 [I] klustakwik Trying to split clusters
#
# 12:56:22 [I] klustakwik Split into 59 clusters
#
# 12:56:23 [I] klustakwik Iteration 90F: 59 clusters, 0 changed, score=-7505682.209360 (decreased by 46.593660)
#
# 12:56:23 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:56:23 [I] klustakwik Trying to split clusters
#
# 12:56:50 [I] klustakwik Split into 60 clusters
#
# 12:56:51 [I] klustakwik Iteration 91F: 60 clusters, 1 changed, score=-7505736.390521 (decreased by 54.181161)
#
# 12:56:52 [I] klustakwik Iteration 92F: 60 clusters, 1 changed, score=-7505736.362317 (decreased by -0.028204)
#
# 12:56:54 [I] klustakwik Iteration 93F: 60 clusters, 3 changed, score=-7505736.330655 (decreased by -0.031662)
#
# 12:56:55 [I] klustakwik Iteration 94F: 60 clusters, 1 changed, score=-7505736.252365 (decreased by -0.078290)
#
# 12:56:56 [I] klustakwik Iteration 95F: 60 clusters, 1 changed, score=-7505736.234197 (decreased by -0.018168)
#
# 12:56:57 [I] klustakwik Iteration 96F: 60 clusters, 0 changed, score=-7505736.208154 (decreased by -0.026043)
#
# 12:56:57 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:56:57 [I] klustakwik Trying to split clusters
#
# 12:57:17 [I] klustakwik Split into 62 clusters
#
# 12:57:18 [I] klustakwik Iteration 97F: 62 clusters, 6 changed, score=-7505788.024574 (decreased by 51.816420)
#
# 12:57:19 [I] klustakwik Iteration 98F: 62 clusters, 4 changed, score=-7505772.300676 (decreased by -15.723898)
#
# 12:57:20 [I] klustakwik Iteration 99F: 62 clusters, 1 changed, score=-7505773.552009 (decreased by 1.251333)
#
# 12:57:21 [I] klustakwik Iteration 100F: 62 clusters, 0 changed, score=-7505774.013023 (decreased by 0.461014)
#
# 12:57:21 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:57:21 [I] klustakwik Trying to split clusters
#
# 12:57:44 [I] klustakwik Split into 63 clusters
#
# 12:57:45 [I] klustakwik Iteration 101F: 63 clusters, 2 changed, score=-7505799.265278 (decreased by 25.252255)
#
# 12:57:46 [I] klustakwik Iteration 102F: 63 clusters, 1 changed, score=-7505796.067288 (decreased by -3.197990)
#
# 12:57:47 [I] klustakwik Iteration 103F: 63 clusters, 0 changed, score=-7505796.036999 (decreased by -0.030289)
#
# 12:57:47 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:57:47 [I] klustakwik Trying to split clusters
#
# 12:58:07 [I] klustakwik Split into 64 clusters
#
# 12:58:08 [I] klustakwik Iteration 104F: 64 clusters, 1 changed, score=-7505822.917877 (decreased by 26.880878)
#
# 12:58:09 [I] klustakwik Iteration 105F: 64 clusters, 1 changed, score=-7505825.961021 (decreased by 3.043144)
#
# 12:58:10 [I] klustakwik Iteration 106F: 64 clusters, 2 changed, score=-7505827.826926 (decreased by 1.865905)
#
# 12:58:11 [I] klustakwik Iteration 107F: 64 clusters, 0 changed, score=-7505828.683232 (decreased by 0.856306)
#
# 12:58:11 [I] klustakwik No points changed and last step was full, so trying to split.
#
# 12:58:11 [I] klustakwik Trying to split clusters
#
# 12:58:35 [I] klustakwik No points changed, previous step was full and did not split, so finishing.
#
# 12:58:35 [I] launch:131           The automatic clustering process has finished.
#
# 12:58:35 [I] launch:268           Save the clustering to `/data/isabella/jake/recording_data/r1299/2023-01-24/sorting/recording.kwik`.
#
# 12:58:35 [I] model:1085           Save the Kwik file at `/data/isabella/jake/recording_data/r1299/2023-01-24/sorting/recording.kwik`.
#
# 12:58:35 [I] launch:290           Clustering done!
#
# klusta run time 950.63s
#
# Sorting Complete
#  UnitsSelectionSorting: 62 units - 1 segments - 48.0kHz
# Klusta found 62 non-empty units
# Sorting saved to /data/isabella/jake/recording_data/r1299/2023-01-24/sorting/sort
# UnitsSelectionSorting: 62 units - 1 segments - 48.0kHz
# /home/isabella/anaconda3/envs/env_37/lib/python3.7/site-packages/spikeinterface/core/basesorting.py:122: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   "The registered recording will not be persistent on disk, but only available in memory")
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Run phy on klusta output
import os
import phy.apps.kwik
os.environ["QTWEBENGINE_CHROMIUM_FLAGS"] = "--single-process"

## If tetrodes sorted separately, change channel_group to choose tetrode to display in phy
phy.apps.kwik.kwik_gui(sorting_path/'recording.kwik', channel_group=None, clustering=None)

# %% [markdown]
# ---
# ## Currently unused code:
# <a id="non-klusta"></a>
# #### For use with non-phy-integrated sorters:

# %%
## Highpass filter and reference data, then extract waveforms for use in spikeinterface GUI
## If using klusta, the same thing can be viewed using phy with the blocks above
## This is more useful when using other sorters

# recording = si.load_extractor(base_folder / "preprocessed")
# recording_to_process = recording
# recording_f = spre.bandpass_filter(recording_to_process, freq_min=300, freq_max=6000)
# recording_cmr = spre.common_reference(recording_f, reference='global', operator='median')
# fs = recording_cmr.get_sampling_frequency()

# sorting = si.load_extractor(sorting_path / 'sort')

# we = si.extract_waveforms(recording_cmr, sorting, folder=base_folder / "waveforms", 
#                           load_if_exists=False, overwrite=True)
# print(we)

# # Export to phy
# sexp.export_to_phy(we, output_folder=base_folder / 'phy', 
#           compute_amplitudes=True, compute_pc_features=True, copy_binary=True, peak_sign = 'neg', verbose = True)

# # Run phy on spikeinterface waveform output
# %cd {base_folder}
# !phy template-gui phy/params.py



## Create waveform GUI as webpage, requires some setup steps on a new machine
## Found here: https://spikeinterface.readthedocs.io/en/latest/modules/widgets.html#sorting-view

# import kachery_cloud as kcl
# kcl.init()
# waveforms0 = we.get_waveforms(unit_id=0)
# print(f"Waveforms shape: {waveforms0.shape}")
# template0 = we.get_template(unit_id=0)
# print(f"Template shape: {template0.shape}")
# all_templates = we.get_all_templates()
# print(f"All templates shape: {all_templates.shape}")
# correlograms = spost.compute_correlograms(we)
# amps = spost.compute_spike_amplitudes(we)
# locs = spost.compute_unit_locations(we)
# sim = spost.compute_template_similarity(we)
# sw.plot_sorting_summary(we, backend='sortingview')

# %%
## Recording utils
# recording.annotate(is_filtered=False)
# channel_ids = recording.get_channel_ids()
# print(f'Channel ids: {channel_ids}')

# %% [markdown]
# #### Code to sort using Klusta by individual tetrodes

# %%
#         sortings = {}
#         for group, sub_recording in recordings.items():
#             sorting = ss.run_sorter('klusta', sub_recording, output_folder=f"{base_folder}/sorting", verbose = False, docker_image = False)
#             sortings[group] = sorting
#             print(f"Tetrode {group+1} of {tetrode_count} Done!")
        
#         for i in list(sortings):
#             if i == 0:
#                 sortings_agg = sortings[0]
#             else:
#                 sortings_agg = si.aggregate_units([sortings_agg, sortings[i]])
#         sorting = sortings_agg

## Plot raster plots per tetrode
# for i in range(1,len(sortings)):
#     raster = sw.plot_rasters(sortings)
#     plt.savefig(f'C:/Users/jakes/Documents/recording_data/r1299/2023-01-24/plots/raster_tetrode{i}.png')

# %% [markdown]
# #### Code to generate tetrodes for sorting on individual tetrodes

# %%
## Generate tetrodes (if tetrode recording) and assign to recording channels
# if electrode_type == 'tetrode':
#     ## Function to produce tetrode objects and assign them to a ProbeGroup
#     from utils import generate_tetrodes 
    
#     if (base_folder / "preprocessed").is_dir():
#         recording = si.load_extractor(base_folder / "preprocessed")
#         print('Tetrode recording loaded from previous preprocessing')
#         generate_tetrodes(tetrode_count)

        
#     else:
#         recording = recording.set_probegroup(generate_tetrodes(tetrode_count), group_mode='by_probe')
#         recording_saved = recording.save(folder=base_folder / "preprocessed")
#         print('Tetrode recording saved to "preprocessed" folder')
    
#     recordings = recording.split_by(property='group', outputs='dict')
#     print(f'Recording split into {tetrode_count} tetrodes')

# %% [markdown]
# <a id="install-dependencies"></a>
# ## Install Dependencies

# %%
## Install spike interface if not already installed
# !pip install spikeinterface

## Install klusta and its dependencies if not already installed
# !pip install Cython h5py tqdm
# !pip install click klusta klustakwik2

## Install phy and dependencies if not already installed
# !conda activate si_env
# !pip install PyQt5==5.12.3
# !pip install pyqtwebengine==5.12.1
# !pip install phy --pre --upgrade

## Check which sorters are installed locally
# ss.installed_sorters()
